# %% [markdown]
# # Installing tools that will be used for the Analysis and reading the dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import neattext as nt
import neattext.functions as nfx

pd.reset_option("max_columns")

import warnings

# %%
dataset = pd.read_excel("Covid vaccine dataset.xlsx", sheet_name=3)

# %%
dataset.shape
# Out:
# (1685, 13)

# %%
dataset.head()
# Out:
#   Respondent Age  Gender  COVID-19 Jab?   Race  Any reason for Hesitation  \
# 0      Staff  19       2              1  White                        1.0
# 1    Student  20       2              0  White                        2.0
# 2    Student  19       1              0  White                        2.0
# 3    Student  44       1              0  White                        NaN
# 4      Staff  30       1              1  White                        NaN
#
#                              Reasons for Hesitation  Hesistation Status  \
# 0  Different things about my health in the long run                 NaN
# 1                                               NaN                 3.0
# 2                                               NaN                 3.0
# 3                                               NaN                 3.0
# 4                                               NaN                 0.0
#
#     Trust Level Safety Level    Confidence Level  \
# 0  Mostly trust  Mostly safe  Somewhat confident
# 1  Mostly trust    Very safe      Very confident
# 2  Mostly trust    Very safe      Very confident
# 3           NaN          NaN                 NaN
# 4           NaN          NaN                 NaN
#
#                                       Accessibility   \
# 0                               Making appointments
# 1                                                NaN
# 2  If we were allowed to be exempt from classes f...
# 3                                                NaN
# 4                                                NaN
#
#                                            Obstacles
# 0      Me being an hour and a half away from campus
# 1  inability to have transportation to vaccinatio...
# 2                                        Scheduling
# 3                                                NaN
# 4                                                NaN

# %% [markdown]
# # Filling the Missing Values

# %%
dataset.fillna(method='ffill', inplace=True)

# %%
dataset.isnull().sum()
# Out:
# Respondent                   0
# Age                          0
# Gender                       0
# COVID-19 Jab?                0
# Race                         0
# Any reason for Hesitation    0
# Reasons for Hesitation       0
# Hesistation Status           1
# Trust Level                  0
# Safety Level                 0
# Confidence Level             0
# Accessibility                0
# Obstacles                    0
# dtype: int64

# %% [markdown]
# # Identifying the number of Staff and Students that took the Vaccine

# %%
Hesistation_freq = dataset[["Reasons for Hesitation", "COVID-19 Jab?", "Respondent"]]
Hesistation_freq.groupby(['COVID-19 Jab?', 'Respondent']).count()
# Out:
#                           Reasons for Hesitation
# COVID-19 Jab? Respondent
# 0             Staff                           99
#               Student                       1041
# 1             Staff                          266
#               Student                        279

# %% [markdown]
# ## Text cleaning

# %%
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Owner\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#remove currency
dataset["Reasons for Hesitation"]=dataset["Reasons for Hesitation"].apply(nfx.remove_currency_symbols)
dataset["Reasons for Hesitation"]=dataset["Reasons for Hesitation"].apply(nfx.remove_stopwords)
dataset["Reasons for Hesitation"]=dataset["Reasons for Hesitation"].apply(nfx.remove_numbers)
dataset["Reasons for Hesitation"]=dataset["Reasons for Hesitation"].apply(nfx.remove_currencies)
dataset["Reasons for Hesitation"]=dataset["Reasons for Hesitation"].apply(nfx.remove_bad_quotes)
dataset["Reasons for Hesitation"]=dataset["Reasons for Hesitation"].apply(nfx.remove_special_characters)

dataset["Obstacles"]=dataset["Obstacles"].apply(nfx.remove_currency_symbols)
dataset["Obstacles"]=dataset["Obstacles"].apply(nfx.remove_stopwords)
dataset["Obstacles"]=dataset["Obstacles"].apply(nfx.remove_numbers)
dataset["Obstacles"]=dataset["Obstacles"].apply(nfx.remove_currencies)
dataset["Obstacles"]=dataset["Obstacles"].apply(nfx.remove_bad_quotes)
dataset["Obstacles"]=dataset["Obstacles"].apply(nfx.remove_bad_quotes)
dataset["Obstacles"]=dataset["Obstacles"].apply(nfx.remove_special_characters)


dataset["Accessibility "]=dataset["Accessibility "].apply(nfx.remove_currency_symbols)
dataset["Accessibility "]=dataset["Accessibility "].apply(nfx.remove_stopwords)
dataset["Accessibility "]=dataset["Accessibility "].apply(nfx.remove_numbers)
dataset["Accessibility "]=dataset["Accessibility "].apply(nfx.remove_currencies)
dataset["Accessibility "]=dataset["Accessibility "].apply(nfx.remove_bad_quotes)
dataset["Accessibility "]=dataset["Accessibility "].apply(nfx.remove_special_characters)

# %%
dataset["Accessibility "].unique()
# Out:
# array(['Making appointments', 'allowed exempt classes day',
#        'streamlined clinic makes getting vaccine simple situation',
#        'Email updates eligibility', 'distributed hours early later  Ex  ',
#        'Good Info',
#        'harmful effects infertility perfectly healthy want new conditions arise vaccine thats year',
#        'location close campus possible', 'places vaccine',
#        'tested housing', 'sure', 'Invite email', 'Week school',
#        'Appt times receive', 'walkability', 'appointment times',
#        'Close home', 'location', 'parking', 'Close distance',
#        'Nothing needed order receive vaccine', 'Na', 'plan getting',
#        'campus site', 'information safety vaccine', 'want date vaccine',
#        'proximity campus', 'Appalachian state campus Boone', 'Idk',
#        'available campus', 'vaccine given campus',
#        'told covid vaccine takes location', 'transportation',
#        'medical setting receive', 'available times long wait times',
#        'Flexible time slots', 'Flexible Scheduling', 'free cheese pizza',
#        'relatively close vaccination location', 'walking distance campus',
#        'local places',
#        'school organizes process vaccination well Meaning people want vaccine cause process clustered difficult appointmentvaccine',
#        'University holidayability work schedule',
#        'nothing dont trust CDC WHO government corruption deep state goals unaware of wont recommend',
#        'dont feel comfortable getting it change', 'Making close',
#        'Multiple vaccine locations constant emailing schedules',
#        'Email Voice call Im hard hearing busy miss call',
#        'vaccine come instead walking campus I live Bowie',
#        'Easy location administration assurance university free stuff',
#        'Flexible scheduling transporting',
#        'making campus car campus locations try bus decrease covid exposure',
#        'elected officials it probably wouldnt it',
#        'exact date time need it', '',
#        'Nothing easy accept getting vaccine',
#        'Time research specifically',
#        'Look Im concerned virus affects personally wear mask follow guidelines sake others feel urgency vaccinated like that available free eventually normal fear Covid',
#        'wont it',
#        'Availability vaccine weekendsoutside normal work hours',
#        'university host vaccination site',
#        'Opening times vaccine students',
#        'uni let know email sign vaccine appt', 'Nothing questions asked',
#        'Flexible appointments hours passes late work professors', 'day',
#        'Knowing', 'Understanding sign vaccine', 'Taking room nurse',
#        'mobile vaccine long wait', 'clear communication',
#        'Maybe kind like drive service vaccine available going stop getting vaccine main priority right trying power vaccine',
#        'location datestimes available',
#        'Info advance making process fast',
#        'Knowing revive COVID vaccination',
#        'sure place currently system makes easy appointment best',
#        'available location near',
#        'Potential transportation oncampus site',
#        'didnt travel far vaccine', 'offered campus',
#        'large range dates times vaccine Preferably Boone',
#        'Im getting later today people Id available weekends',
#        'ability vaccine campus lots different appointment times available university sending emails step step information links appointment',
#        'immediately easier', 'Tents East west', 'wouldnt',
#        'vaccine available close home',
#        'supplied date information vaccine safety',
#        'Specific time up vaccine absolutely day',
#        'Offer afternoon weekday Im swamped homework day saturday prefer hiking needle arm',
#        'Vaccine clinic campus easier walk', 'information',
#        'proper information it', 'Nothing ready vaccine protect others',
#        'Easily accessible vaccination site',
#        'Information clinic procedures mentally prepare myself I like needles',
#        'Location', 'Clarity effects available campus', 'Organization',
#        'Quick appointment campus', 'dont want',
#        'free charge close current location', 'choose day', 'time work',
#        'Flexible times drive through visits', 'availability time slots',
#        'campus administration', 'Access', 'Nothing',
#        'doctors approval information vaccines', 'IDC want it',
#        'Easy system reading information making appointment',
#        'matter ease reason person vaccination',
#        'Assuring extremely bad going happen me', 'Transportation site',
#        'COVID threat actually is',
#        'Making available times day order sure people able worry job responsibilities',
#        'notification able vaccine', 'drive upwalk sites',
#        'actually vaccine', 'reason shot able mom Assisted Living Center',
#        'specific time vaccine an appointment sure wait line miss class sure Ill it',
#        'notified asap easy appointment making',
#        'large quantity vaccine multiple places it allow register no waiting lists receive vaccine efficient manner',
#        'availability multiple times available',
#        'want forced Vaccine know effects of extensive research spread news outlets comfortable taking it',
#        'lying', 'Nothing refuse it', 'insane wait ie long line',
#        'administered campus', 'appointment didnt wait long lines',
#        'provided hours drive', 'App State allow drive receive it',
#        'prefer vaccine', 'Id fine driving little distance order it',
#        'live life normally getting vaccine  ie masks traveling thats cancelled covid',
#        'Im getting tomorrow', 'lots available times receive vaccine',
#        'knowing Im able safe free', 'require it',
#        'vaccinate lethality low spread miniscule chance getting reinfected lower',
#        'getting easily accessible place', 'Transportation',
#        'Clarity specificity rules safe distribution locations',
#        'Return normalcy',
#        'data testing success rates vaccine vaccine utilized things morals process creation',
#        'wide range appointment times', 'Availability',
#        'Large range time  stay available longer day',
#        'General Accessibility', 'Easy appointment setup', 'legit',
#        'Close vaccination site', 'Verifying doctor good time', 'campus',
#        'told there', 'Knowing kind vaccine able get', 'close',
#        'safer vaccine', 'close vaccine',
#        'mental health days like promised students break',
#        'lots options opportunities vaccine sharing information parents general public persuade safe',
#        'Choice location vaccine Choice vaccine able',
#        'Nothing getting it',
#        'multiple vaccine clinics campus including health sciences building Maybe block room academic building vaccine distribution way people access possible matter campus Maybe dorm lobbies too safest option still',
#        'Knowledge effects', 'fact vaccine wasnt created year',
#        'sign service online', 'Campus offering students eligible',
#        'Email ahead time', 'Location information',
#        'Giving campus walking distance dorm', 'use stem cells research',
#        'available campus multiple days times one',
#        'able book appointments online rather phone calls appointments necessary',
#        'Im sure', 'it', 'right',
#        'transparency vaccine requiring attend classes', 'far campus ride',
#        'Easy way sign', 'want wait watch vaccine interacts chose vaccine',
#        'nothing easy', 'Easy access', 'campus like covid tests were',
#        'giving days vaccinei cant dates given wait wont let select day',
#        'Close proximity', 'Easily accessible location', 'know',
#        'Paid time away work', 'nurse came officejust kidding',
#        'Appointments App Healthcare email saying appointment',
#        'location campus walk', 'Getting instructions email getting it',
#        'Getting choose specific appointment time', 'able choose',
#        'Morning availability', 'Nothing it', 'know information cdc',
#        'Availability vaccine later night school hours work hours usual day',
#        'scheduled vaccine', 'Getting scheduled vaccine',
#        'Vaccine clinics campus', 'yes', 'Im getting',
#        'Multiple times available', 'Knowing wont wont affect future',
#        'want vaccine', 'classes', 'informed soon possible',
#        'Knowing components allergy test', 'took', 'Free',
#        'receive campus', 'location campus', 'Knowing said vaccine',
#        'offered campus appointment slots', 'location near',
#        'chance bad reaction', 'money', 'Nothing excited turn',
#        'matter what', 'wanted', 'advanced notice',
#        'Ease schedulingworking schedule',
#        'dont want thats all dont flu vaccine theyre thing',
#        'locations vaccine campus',
#        'dont live campus available local doctors office easier driving Boone',
#        'convenient location free', 'Getting vaccine App getting TN',
#        'Facts research', 'Location Times Cost friendly ect',
#        'Im getting later today', 'vaccine campus', 'Persuasive pamphlet',
#        'detailed write vaccine including science works possible effects',
#        'transportation supportive family body autonomy',
#        'Let family vaccinated', 'cant easier', 'app distributed',
#        'Drive stations similar App state testing legends',
#        'Getting info receiving it',
#        'open appointment Im eligible fully booked live Charlotte Rock Hill',
#        'vaccine distributed campus', 'communication',
#        'campus wi walking distance', 'Easy sign clear process',
#        'sign time', 'Getting information it', 'Weekend distribution',
#        'Flexible timinglocation',
#        'campus sites resources schedule campus',
#        'Knowing friends community getting', 'its close',
#        'location available', 'fact its campus',
#        'Easily accessible in area Im familiar with',
#        'knew vaccines actually safe long run',
#        'Wide range appointments times better fit schedule',
#        'Knowing works doesnt cause future health problems',
#        'Nothing Im taking', 'Close house flexible hours', 'Transport',
#        'provided steps', 'Ease getting location wise',
#        'didnt school work focus time deal affects',
#        'Clear scheduling practices proximity work home',
#        'drive campus i live lenoir offered weekend', 'research',
#        'readily available close me',
#        'Offer  vaccines limit want have choice this', 'Campus location',
#        'Knowing people got', 'knowing', 'Location campus',
#        'Johnson Johnson vaccination', 'school way covid tests right',
#        'Working overall busy schedule', 'publicized information',
#        'time  need information long term effects vaccine',
#        'regardless Im ready', 'really Its dont find difficult',
#        'Clear communication when where',
#        'vaccines offered consistent organized fashion',
#        'Successful results students taken', 'Receive close home',
#        'Orderly Accessibility',
#        'vaccine given close dorm weekend impact classes',
#        'setup similar testing events taken place out',
#        'Free charge location close campusmy apartment',
#        'studies possible health concerns related vaccine',
#        'good location',
#        'opportunity closer home travel App States campus receive dose',
#        'Convenience getting physical injection', 'vaccine',
#        'Transportation physical access location vaccine site',
#        'Years study long term effect people politicization virus vaccine',
#        'information know sign', 'taking', 'knowing long term risks low',
#        'wide range times available vaccine offering multiple oncampus locations',
#        'couple days break vaccine feel little weather after',
#        'like information longterm effects fillers vaccine',
#        'places vaccinated', 'pop clinics everyday large range time',
#        'Proximity', 'Easy signup local availability', 'text phone',
#        'information effects', 'Data effects preventativeness vaccine',
#        'Smooth efficient administering vaccines vaccination site',
#        'mandatory travel country', 'Evidence negative effects',
#        'Announcing school',
#        'Flexibility time slots IE time slots evening weekends',
#        'Free chocolate', 'Unsure',
#        'chart possible symptoms readily available',
#        'Distribution vaccines peoples cars standing large lines crowds',
#        'Close campus easy set appointment', 'Vaccine offered campus',
#        'easy location', 'Scheduling options work classes',
#        'nothing intend vaccinated time',
#        'Mode transportation close proximity campus',
#        'Getting vaccine campus ideal dont car',
#        'Scheduling like rapid testing opposed popups walkins volume people seeking vaccine time unknown',
#        'change mind feel necessary it', 'feel better',
#        'Time schoolexcused absence class', 'alternative Johnson Johnson',
#        'accessibility', 'signed one Emails helped', 'matter',
#        'Able campus drive', 'Getting vaccine campus',
#        'campus vaccinations', 'Ability appointment weeks notice',
#        'easier vaccine closer home', 'campus near campus fine',
#        'Accessability', 'walking distance dorm', 'provided school',
#        'App State provided vaccine', 'Local distribution sites',
#        'vaccine available receive', 'place campus', 'Guarantees Heath',
#        'schedule appointment specific date time',
#        'campus receive vaccination possibly times clinic open',
#        'dispensed nearby location', 'Army required it',
#        'Research vaccine', 'letting know it information available email',
#        'accessability distribution center close campus bus route oncapmus students',
#        'close living', 'campus vaccine sites',
#        'Making sure allergic reaction', 'email notification',
#        'didnt appointment',
#        'knowing people need at risk population older folks frontline workers got',
#        'easy access close campus', 'Free charge nearby',
#        'Im interested getting vaccine right now', 'Good communication',
#        'records getting vaccine insurance and mother access insurance info sees it lot trouble family maybe maybe like anonymous something',
#        'Email updates easier scheduling variety time slots', 'nothing',
#        'transparencyadvice exactly schedule prepare vaccine',
#        'campus location vaccine', 'free',
#        'Creating appointment gets vaccine people time',
#        'Attendance Waiver class class time', 'Dates',
#        'studies effects vaccine time passed people getting vaccine',
#        'available campus pharmacy Boone', 'oncampus',
#        'appointment app state appointment time up',
#        'Im getting Wednesday', 'email including details process',
#        'Ease location',
#        'perfectly onboard getting vaccine soon available sure vaccine processes fast possible safe',
#        'know long term effects',
#        'proximity public bathrooms anxietyrelated reactions injections weekend availability',
#        'vaccine given Boone', 'able appointment time',
#        'Vaccinations Legends', 'NOTHINGNEVER going', 'lol',
#        'Variety dates vaccines getting issued', 'flexible schedule',
#        'wait school year academics symptoms combine cause stress',
#        'able choose appointment time accommodates work class schedule',
#        'Email communication',
#        'close location dorm possibility separate testing area sides campus',
#        'Nothing Im getting', 'wouldnt need anything soon could',
#        'Telling group available',
#        'accessible campus neighboring pharmacy',
#        'Knowing actual vaccine research',
#        'Ease scheduling safe socially distanced area vaccine',
#        'better explanation qualifies stagehow physically getting it',
#        'Time', 'Drivethru', 'send email lmk',
#        'given appointment works class schedule', 'Tell it',
#        'told available', 'Nothing definitely',
#        'Location knowledge kind vaccine', 'campus vaccination',
#        'waiting list lines crowds avoided', 'research outcomeresults',
#        'vaccine shown foolproof accuracy protecting virus',
#        'University reach sign time slot receive it', 'easier',
#        'organized accessible way distributing vaccines',
#        'scheduled tomorrow App State', 'questions asked', 'Text updates',
#        'vaccine availability times', 'Easy sign', 'cost',
#        'email providing information instruction',
#        'Wide spread information getting vaccine',
#        'multiple clinics set campus instead location',
#        'able walk ins schedule appointment', 'Emails',
#        'knew fact immune getting covid', 'place town',
#        'Giving choice not making able daily business giving vaccinated abilities gather wear masks incentivise getting vaccinated',
#        'University providing vaccines', 'given campus', 'taking vaccine',
#        'streamline simple process vaccine ASU', 'Accessibility',
#        'vaccine offered students working home finding locations',
#        'Knowing dose', 'want wait plays longer course time',
#        'Drop vaccinations time reservations',
#        'Getting handcuffed dragged heels',
#        'set time available worry missing schedule',
#        'multiple days andor time order receive it location close campus preferably walking distance',
#        'flexible time done', 'plan getting vaccine', 'teleport',
#        'Oncampus vaccines', 'Set timing avoid lines',
#        'Viewing effective rates vaccine',
#        'Alert openings appointments receiving vaccine',
#        'Receiving info time flexibility got',
#        'email describing exactly recieve it', 'appointment time',
#        'Unquestionable evidence wont cause harm ability produce healthy baby',
#        'fast efficient process', 'school',
#        'Definitely availability frequent communication Its hard know sign',
#        'accessible transportation', 'Convenient location',
#        'Appropriate times receive work time', 'cant think easier easy me',
#        'options days times', 'Provide data surrounding long term effects',
#        'Giving multiple appointment times', 'Mobile vaccine clinic',
#        'Wide choice hours receive', 'convenient time location',
#        'Drive clinic flexible hours',
#        'information effects trial information',
#        'clear email telling sign', 'Ill its right thing regardless',
#        ' getting vaccine', 'form sign quickly', 'Setting appointment',
#        'Access campus easy follow instructions', 'wont leave it',
#        'unsure want vaccine', 'Nothing COVID vaccine',
#        'flexible schedule due classes facilities easy walking distance campus',
#        'list possibly allergic reactions come vaccine',
#        'Availability weekends class time', 'gets vaccine',
#        'Provided university flexibility scheduling appointment location campus',
#        'Notified', 'Offered campus time convenient class schedule',
#        'Knowing carry disease Not concerned COVID carrier it',
#        'positive results people gotten vaccine',
#        'provden affects internal organs time',
#        'Spread informationawareness whenwhere it',
#        'Hearing students vaccine', 'shot vaccine',
#        'schedueled times people vaccine',
#        'Notifying available email location campus', 'getting JJ vaccine',
#        'campus locations', 'actually email schedule',
#        'email updates campus vaccine sites',
#        'able receive vaccine oncampus', 'nearby',
#        'qualifying age teach remotely until vaccine',
#        'Clear information qualify', 'Multiple time slots vaccine',
#        'Knowing common effects likelihood occurring receiving vaccine',
#        'Nothing Im getting vaccine', 'Better information communication',
#        'reassurance safe approval family members',
#        'Easily able appointment',
#        'closer end day closer end week awesome weekend',
#        'onsite deliverable', 'Information it',
#        'free distributed  hours away definitely', 'day class',
#        'Nothing want it',
#        'place nearby receive vaccine walking distance campus bus system',
#        'Times outside normal business hours',
#        'Multiple clinics offered ASU campus', 'free meal gift card',
#        'contact manshooryaappstateedu', 'announcements it',
#        'Accessibility vaccine hometown', 'research long term effects',
#        'Multiple timesdays availability', 'given information vaccine',
#        'access nearby campus minutes drive',
#        'large window time reserve time slot nearby vaccination center',
#        'Getting paper information cdc effects advice deal',
#        'way hell vaccine', 'roommates vaccinated', 'interested time',
#        'email detailing need go schedule vaccineetc',
#        'available work everyday dealing students faculty staff Boone community',
#        'lots time slots work willing time', 'free time',
#        'going vaccine want  effective JJ vaccine honestly isnt worth dont trust Pfizer moderna',
#        'Learning information effects people', 'campus clinic',
#        'Email notification',
#        'vaccination site campus possibly drivethrough',
#        'multiple flexible datestimes available appointments',
#        'lowcost free', 'Letting know Right informed vaccine availability',
#        'near', 'Reassurance',
#        'want indepth information Right now feels like act faith',
#        'Absolutely nothing', 'Confidence', 'campus walk',
#        'Easier accessibility wait time', 'campus sites',
#        'Honestly cant think easier Possibly people constantly telling need vaccinated place tell people decision',
#        'Nothing going lot thinking vaccine dont say protecting other worries year research it',
#        'appointment slots availability', 'dont desire vaccine',
#        'allowing closer home set time afternoon app', 'close campus',
#        'Accessibility wider range time', 'campus vaccine location',
#        'able hometownnot come App', 'personal obligation month',
#        'wasnt time waiting line',
#        'vaccine appointment occur Friday weekend',
#        'Notification availabilityeasy sign',
#        'Schedule appointment wait long time',
#        'forcing letting time personally feel comfortable',
#        'provided campus', 'no', 'clear list eligible sign',
#        'Flexible timeframe',
#        'different vaccines available johnson johsnon data general preexisitng health conditions',
#        'Emailing directly appstate email calling',
#        'access vaccine personal concerns choosing vaccinated time',
#        'family encouragement',
#        'Knowing specifically Johnson Johnson shot vaccine phobia needles',
#        'Yes', 'JohnsonJohnson vaccines available',
#        'information opportunity vaccinated university provided adequate information help plan actions',
#        'setting appointment', 'given place easy access long waiting line',
#        'Large vaccination events like Convocation   lots different appointment times day',
#        'close campus car',
#        'Home delivery transportation distribution site',
#        'flexibility time COVID testing limited options like able time work  days',
#        'wear mask great again', 'Available campus', 'dont know',
#        'Busses straight there campus administration',
#        'Im hesitant work unknown longterm effects',
#        'prior notice clear instructions', 'Email updates availability',
#        'wait long line', 'easy signup google forms similar',
#        'different times days able vaccine packed schedule hard wait long line limited choices revived vaccine dont lot free time',
#        'Rapid abundant information vaccination sites', 'FDA approval',
#        'Nothing view COVID similar flu going vaccine going sick rarely sick spend time people person need vaccine time',
#        'Knowing effects future', 'accessible close campus',
#        'available town west Jefferson', 'Wait  years future effects',
#        'email instructions', 'Proof vaccine works cause terrible effects',
#        'choosing vaccine unknown longshort term effects',
#        'accessibility communication', 'im getting', 'Ease sign',
#        'know sure group fall window changed',
#        'receiving information email',
#        'email stating developer vaccine assuming CDC cleared Astrazeneca vaccine yet',
#        'Lots emails telling information order vaccine',
#        'Easy inandout delivery',
#        'vaccine developed year know affect fivemy body choice',
#        'actual clinical trial rushed', 'quick',
#        'campus distribution free charge', 'Flexible scheduling classes',
#        'location appointment vaccince', 'its easy find',
#        'sending emails notifying students vaccination sites campus online',
#        'dont want vaccine', 'piece mind',
#        'Places campus available set times sign', 'Scheduling',
#        'available campus living students close quarters like',
#        'email textphone communication', 'Nothing Id',
#        'its given MondayWednesday', 'Offered campus',
#        'multiple dates time windows vaccine help most', 'school free',
#        'Pfizer vaccine', 'Giving days notice plan accordingly',
#        'location easily accessible campus car',
#        'Easier acess information confirm appointment high risk individual Group  medical records whom person online etc',
#        'dont think vaccine probably long time',
#        'Johnson  Johnson vaccine needed dose', 'Emails sign up',
#        'vaccine close residence hall walk way campus one', 'want',
#        'safe area receive vaccine knowing sterile sanitized people administering knew doing',
#        'Variable flexible times safe conditions',
#        'help appointment scheduling', 'Data efficacy safety',
#        'Clear communication', 'Easily accessible vaccination sites',
#        'Walk day appointments',
#        'Nothing its wasted college students old people need health concerns',
#        'convenient location campus', 'location vaccine campus',
#        'Im getting vaccine', 'vaccination site close apartment',
#        'Information', 'Accessibility ability schedule',
#        'complete information ingredients', 'close house drive campus it',
#        'campus vaccination site', 'notification when how',
#        'available locations',
#        'making sure effectiveness high ones exists for instance far Pfizer',
#        'Appointment times', 'weekend',
#        'walking distance dorm campus dont car', 'availability', 'Blank',
#        'car willingness wait lines', 'Knowing protect people family',
#        'Governor cooper needs stop fucking let eligible',
#        'Lots available dates times', 'location close live',
#        'Available test sites', 'Knowing wont harm long run', 'wont',
#        'Lots hours availability',
#        'EmailText notification eligibility  vaccinated',
#        'organized efficient system distributing vaccine', 'Close live',
#        'getting vaccine tomorrow',
#        'notices vaccine hard register vaccine group currently vaccinating',
#        'Good information how good organisation system', 'close facility',
#        'years testing completely prove safety',
#        'appointmentbased system easy schedule vaccination appointment',
#        'Free charge', 'Clarity', 'noting',
#        'benefits assurances big names school receiving',
#        'clinics outside forms', 'dose vs ', 'Email updates',
#        'Appointments', 'Incentives', 'vaccinated outcomes',
#        'dont want forced taking it Ill Im ready', 'Letting know',
#        'vaccine clinics app state providing helpful', 'Nasal spray',
#        'didnt work', 'Easy access vaccination areas',
#        'given campus easily', 'available appointments', 'complications',
#        'easy', 'Home vaccination', 'time', 'knowledge effects',
#        'Convenient time', 'school supplying it', 'Walkin appointments',
#        'faculty reach info recieve vaccine',
#        'flexible time frames easily accessed location', 'proximity',
#        'Close location choice timedate appointment',
#        'Provided transportation vaccination sites', 'id forced it',
#        'information effectiveness',
#        'knowledge steps order acquire vaccine', 'advertising',
#        'open schedule ease transportation',
#        'email saying specifically available receive vaccine',
#        'research extent completely understand affect me',
#        'Johnson  Johnson vaccine', 'dose tomorrow',
#        'research needed like long term effects', 'ASU', 'confidence',
#        'vaccine available campus', 'knowing sign sign',
#        'Pop clinics set major appt complexes',
#        'Mail delivery vaccines way distribute locally'], dtype=object)

# %% [markdown]
# ## Tokenization

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
from nltk.tokenize import sent_tokenize, word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Owner\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Owner\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
dataset["Obstacles_tk"] = [word_tokenize(i) for i in dataset["Obstacles"]]
dataset["Reasons for Hesitation_tk"] = [word_tokenize(i) for i in dataset["Reasons for Hesitation"]]
dataset["Accessibility_tk "] = [word_tokenize(i) for i in dataset["Accessibility "]]

# %%
print(dataset["Obstacles_tk"])
# Out:
# 0                            [hour, half, away, campus]
# 1       [inability, transportation, vaccination, sites]
# 2                                          [Scheduling]
# 3                                          [Scheduling]
# 4                                          [Scheduling]
#                              ...
# 1680                      [vaccines, offered, oncampus]
# 1681                      [vaccines, offered, oncampus]
# 1682                      [vaccines, offered, oncampus]
# 1683                      [vaccines, offered, oncampus]
# 1684                      [vaccines, offered, oncampus]
# Name: Obstacles_tk, Length: 1685, dtype: object

# %% [markdown]
# # Lemmatization

# %%
# import these modules
nltk.download('omw-1.4')
from nltk.stem import WordNetLemmatizer  
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Owner\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
for i in dataset["Obstacles"]:
    print("Original Word: {} \t Lemmatized word:{}".format(i, lemmatizer.lemmatize(i)))
# Out:
# Original Word: hour half away campus 	 Lemmatized word:hour half away campus
# Original Word: inability transportation vaccination sites 	 Lemmatized word:inability transportation vaccination sites
# Original Word: Scheduling 	 Lemmatized word:Scheduling
# Original Word: Scheduling 	 Lemmatized word:Scheduling
# Original Word: Scheduling 	 Lemmatized word:Scheduling
# Original Word: Scheduling 	 Lemmatized word:Scheduling
# Original Word: personal phobia needles biggest hurdle 	 Lemmatized word:personal phobia needles biggest hurdle
# Original Word: personal phobia needles biggest hurdle 	 Lemmatized word:personal phobia needles biggest hurdle
# Original Word: Lack communication appointment availability 	 Lemmatized word:Lack communication appointment availability
# Original Word: Lack communication appointment availability 	 Lemmatized word:Lack communication appointment availability
# Original Word: Lack communication appointment availability 	 Lemmatized word:Lack communication appointment availability
# Original Word: Lack communication appointment availability 	 Lemmatized word:Lack communication appointment availability
# Original Word: Lack communication appointment availability 	 Lemmatized word:Lack communication appointment availability
# Original Word: hours limited 	 Lemmatized word:hours limited
# Original Word: hours limited 	 Lemmatized word:hours limited
# Original Word: tight time slot 	 Lemmatized word:tight time slot
# Original Word: tight time slot 	 Lemmatized word:tight time slot
# Original Word: Its money its research prove safety effectiveness 	 Lemmatized word:Its money its research prove safety effectiveness
# Original Word: Its money its research prove safety effectiveness 	 Lemmatized word:Its money its research prove safety effectiveness
# Original Word: Its money its research prove safety effectiveness 	 Lemmatized word:Its money its research prove safety effectiveness
# Original Word: Availability appetizers 	 Lemmatized word:Availability appetizers
# Original Word: Availability appetizers 	 Lemmatized word:Availability appetizers
# Original Word: Difficult access 	 Lemmatized word:Difficult access
# Original Word: physically inaccessible 	 Lemmatized word:physically inaccessible
# Original Word: physically inaccessible 	 Lemmatized word:physically inaccessible
# Original Word: physically inaccessible 	 Lemmatized word:physically inaccessible
# Original Word: physically inaccessible 	 Lemmatized word:physically inaccessible
# Original Word: physically inaccessible 	 Lemmatized word:physically inaccessible
# Original Word: practice meets sickness 	 Lemmatized word:practice meets sickness
# Original Word: practice meets sickness 	 Lemmatized word:practice meets sickness
# Original Word: practice meets sickness 	 Lemmatized word:practice meets sickness
# Original Word: practice meets sickness 	 Lemmatized word:practice meets sickness
# Original Word: sure 	 Lemmatized word:sure
# Original Word:  	 Lemmatized word:
# Original Word: week school 	 Lemmatized word:week school
# Original Word: Boone doable preferred 	 Lemmatized word:Boone doable preferred
# Original Word: Boone doable preferred 	 Lemmatized word:Boone doable preferred
# Original Word: location outside Boone 	 Lemmatized word:location outside Boone
# Original Word: location outside Boone 	 Lemmatized word:location outside Boone
# Original Word: Scheduling transportation 	 Lemmatized word:Scheduling transportation
# Original Word: Farther home 	 Lemmatized word:Farther home
# Original Word: Farther home 	 Lemmatized word:Farther home
# Original Word: Farther home 	 Lemmatized word:Farther home
# Original Word: Farther home 	 Lemmatized word:Farther home
# Original Word: Farther home 	 Lemmatized word:Farther home
# Original Word: Farther home 	 Lemmatized word:Farther home
# Original Word: Weird time slots 	 Lemmatized word:Weird time slots
# Original Word: High demand 	 Lemmatized word:High demand
# Original Word: High demand 	 Lemmatized word:High demand
# Original Word: High demand 	 Lemmatized word:High demand
# Original Word: High demand 	 Lemmatized word:High demand
# Original Word: Transportation possible issue 	 Lemmatized word:Transportation possible issue
# Original Word: Na 	 Lemmatized word:Na
# Original Word: Na 	 Lemmatized word:Na
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word
# Original Word: sure 	 Lemmatized word:sure
# Original Word: sure 	 Lemmatized word:sure
# Original Word: understanding sign vaccine knowing eligible it 	 Lemmatized word:understanding sign vaccine knowing eligible it
# Original Word: Phobia Shots 	 Lemmatized word:Phobia Shots
# Original Word: wait long lines 	 Lemmatized word:wait long lines
# Original Word: wait long lines 	 Lemmatized word:wait long lines
# Original Word: misleading communication unflexible time frame 	 Lemmatized word:misleading communication unflexible time frame
# Original Word: think anything 	 Lemmatized word:think anything
# Original Word: think anything 	 Lemmatized word:think anything
# Original Word: think anything 	 Lemmatized word:think anything
# Original Word: think anything 	 Lemmatized word:think anything
# Original Word: think anything 	 Lemmatized word:think anything
# Original Word: studentspeople wearing maskssocially distancing getting COVID  forcing family quarantine again and thus cancel vaccine appointments P 	 Lemmatized word:studentspeople wearing maskssocially distancing getting COVID  forcing family quarantine again and thus cancel vaccine appointments P
# Original Word: Time conflict 	 Lemmatized word:Time conflict
# Original Word: Time conflict 	 Lemmatized word:Time conflict
# Original Word: Im near campus 	 Lemmatized word:Im near campus
# Original Word: Im near campus 	 Lemmatized word:Im near campus
# Original Word: time line getting vaccine went past end semester NY 	 Lemmatized word:time line getting vaccine went past end semester NY
# Original Word: time line getting vaccine went past end semester NY 	 Lemmatized word:time line getting vaccine went past end semester NY
# Original Word: available campus 	 Lemmatized word:available campus
# Original Word: think 	 Lemmatized word:think
# Original Word: Long waits 	 Lemmatized word:Long waits
# Original Word: Long waits 	 Lemmatized word:Long waits
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word: travel receive 	 Lemmatized word:travel receive
# Original Word: forth home school frequently vaccine date fall day campus 	 Lemmatized word:forth home school frequently vaccine date fall day campus
# Original Word: Limited hours far away 	 Lemmatized word:Limited hours far away
# Original Word: Timing offered midterm week 	 Lemmatized word:Timing offered midterm week
# Original Word: Timing offered midterm week 	 Lemmatized word:Timing offered midterm week
# Original Word: fewer locations available appointment times lack information howwhere appointment 	 Lemmatized word:fewer locations available appointment times lack information howwhere appointment
# Original Word: fewer locations available appointment times lack information howwhere appointment 	 Lemmatized word:fewer locations available appointment times lack information howwhere appointment
# Original Word: specific time time class time day practicum difficult rearrange vaccine 	 Lemmatized word:specific time time class time day practicum difficult rearrange vaccine
# Original Word: appointment 	 Lemmatized word:appointment
# Original Word: wouldnt 	 Lemmatized word:wouldnt
# Original Word: wouldnt 	 Lemmatized word:wouldnt
# Original Word: vaccine available near 	 Lemmatized word:vaccine available near
# Original Word: Knowing high rate severe fatal effects 	 Lemmatized word:Knowing high rate severe fatal effects
# Original Word:  	 Lemmatized word:
# Original Word: time offered long wait line Waiting lines mask social distancing freaks feels dystopian 	 Lemmatized word:time offered long wait line Waiting lines mask social distancing freaks feels dystopian
# Original Word: Long wait times 	 Lemmatized word:Long wait times
# Original Word: Long wait times 	 Lemmatized word:Long wait times
# Original Word: seeing people react 	 Lemmatized word:seeing people react
# Original Word: seeing people react 	 Lemmatized word:seeing people react
# Original Word: Scheduling issues 	 Lemmatized word:Scheduling issues
# Original Word: Failed efficacy increased reactions 	 Lemmatized word:Failed efficacy increased reactions
# Original Word: Finding free moment it 	 Lemmatized word:Finding free moment it
# Original Word: Finding free moment it 	 Lemmatized word:Finding free moment it
# Original Word: Aggressivepushy advertising 	 Lemmatized word:Aggressivepushy advertising
# Original Word: Aggressivepushy advertising 	 Lemmatized word:Aggressivepushy advertising
# Original Word: Aggressivepushy advertising 	 Lemmatized word:Aggressivepushy advertising
# Original Word: multiple allergies life threatening 	 Lemmatized word:multiple allergies life threatening
# Original Word: Requirements 	 Lemmatized word:Requirements
# Original Word: effects drive somewhere inconvenience 	 Lemmatized word:effects drive somewhere inconvenience
# Original Word: effects drive somewhere inconvenience 	 Lemmatized word:effects drive somewhere inconvenience
# Original Word: effects drive somewhere inconvenience 	 Lemmatized word:effects drive somewhere inconvenience
# Original Word: waiting crowding 	 Lemmatized word:waiting crowding
# Original Word: waiting crowding 	 Lemmatized word:waiting crowding
# Original Word: waiting crowding 	 Lemmatized word:waiting crowding
# Original Word: waiting crowding 	 Lemmatized word:waiting crowding
# Original Word: waiting crowding 	 Lemmatized word:waiting crowding
# Original Word:  	 Lemmatized word:
# Original Word: dont want 	 Lemmatized word:dont want
# Original Word: dont want 	 Lemmatized word:dont want
# Original Word: far away located 	 Lemmatized word:far away located
# Original Word: certain time 	 Lemmatized word:certain time
# Original Word: certain time 	 Lemmatized word:certain time
# Original Word: time 	 Lemmatized word:time
# Original Word: time 	 Lemmatized word:time
# Original Word: Overload people signing similar times 	 Lemmatized word:Overload people signing similar times
# Original Word: advertising competitive time slots 	 Lemmatized word:advertising competitive time slots
# Original Word: Getting appointment 	 Lemmatized word:Getting appointment
# Original Word: Anxiety 	 Lemmatized word:Anxiety
# Original Word: research time up 	 Lemmatized word:research time up
# Original Word: knowing long term effects 	 Lemmatized word:knowing long term effects
# Original Word: knowing long term effects 	 Lemmatized word:knowing long term effects
# Original Word: limited times 	 Lemmatized word:limited times
# Original Word: uninformed unclear procedure schedule appointment 	 Lemmatized word:uninformed unclear procedure schedule appointment
# Original Word: unwillingness vaccine 	 Lemmatized word:unwillingness vaccine
# Original Word: fear bad reaction 	 Lemmatized word:fear bad reaction
# Original Word: Short hours working schedule 	 Lemmatized word:Short hours working schedule
# Original Word: worried sideeffects actual virus 	 Lemmatized word:worried sideeffects actual virus
# Original Word: Making available times common person works 	 Lemmatized word:Making available times common person works
# Original Word: getting notification 	 Lemmatized word:getting notification
# Original Word: getting notification 	 Lemmatized word:getting notification
# Original Word: getting notification 	 Lemmatized word:getting notification
# Original Word: schedule appointment 	 Lemmatized word:schedule appointment
# Original Word: fact COVID going eventually endemic numbers dramatically fall coming days mutate booster shots year Right healthy individual believes need me 	 Lemmatized word:fact COVID going eventually endemic numbers dramatically fall coming days mutate booster shots year Right healthy individual believes need me
# Original Word: fact COVID going eventually endemic numbers dramatically fall coming days mutate booster shots year Right healthy individual believes need me 	 Lemmatized word:fact COVID going eventually endemic numbers dramatically fall coming days mutate booster shots year Right healthy individual believes need me
# Original Word: fact COVID going eventually endemic numbers dramatically fall coming days mutate booster shots year Right healthy individual believes need me 	 Lemmatized word:fact COVID going eventually endemic numbers dramatically fall coming days mutate booster shots year Right healthy individual believes need me
# Original Word: reason above shot 	 Lemmatized word:reason above shot
# Original Word: given campus 	 Lemmatized word:given campus
# Original Word: knowing eligible inability appointment 	 Lemmatized word:knowing eligible inability appointment
# Original Word: knowing eligible inability appointment 	 Lemmatized word:knowing eligible inability appointment
# Original Word: knowing eligible inability appointment 	 Lemmatized word:knowing eligible inability appointment
# Original Word: knowing eligible inability appointment 	 Lemmatized word:knowing eligible inability appointment
# Original Word: knowing eligible inability appointment 	 Lemmatized word:knowing eligible inability appointment
# Original Word: Getting waiting list goes ahead shot happening counties state  year old mother Boone actually vaccine lives Henderson County waiting list vaccination thousand people appointments shot ahead thousands waiting list 	 Lemmatized word:Getting waiting list goes ahead shot happening counties state  year old mother Boone actually vaccine lives Henderson County waiting list vaccination thousand people appointments shot ahead thousands waiting list
# Original Word: Getting waiting list goes ahead shot happening counties state  year old mother Boone actually vaccine lives Henderson County waiting list vaccination thousand people appointments shot ahead thousands waiting list 	 Lemmatized word:Getting waiting list goes ahead shot happening counties state  year old mother Boone actually vaccine lives Henderson County waiting list vaccination thousand people appointments shot ahead thousands waiting list
# Original Word: Nothing 	 Lemmatized word:Nothing
# Original Word: idea forced makes difficult me think fair force vaccine unknown effects people Flu Measles HPV vaccines seen effects years Covid vaccine months 	 Lemmatized word:idea forced makes difficult me think fair force vaccine unknown effects people Flu Measles HPV vaccines seen effects years Covid vaccine months
# Original Word: required essential worker caretaker as neither 	 Lemmatized word:required essential worker caretaker as neither
# Original Word: required essential worker caretaker as neither 	 Lemmatized word:required essential worker caretaker as neither
# Original Word: required essential worker caretaker as neither 	 Lemmatized word:required essential worker caretaker as neither
# Original Word: Nothing refuse it 	 Lemmatized word:Nothing refuse it
# Original Word: insane wait ie like  hours 	 Lemmatized word:insane wait ie like  hours
# Original Word: insane wait ie like  hours 	 Lemmatized word:insane wait ie like  hours
# Original Word: far away 	 Lemmatized word:far away
# Original Word: Time management 	 Lemmatized word:Time management
# Original Word: Time management 	 Lemmatized word:Time management
# Original Word: Time management 	 Lemmatized word:Time management
# Original Word: travel far andor skip work class 	 Lemmatized word:travel far andor skip work class
# Original Word: travel far andor skip work class 	 Lemmatized word:travel far andor skip work class
# Original Word: travel far andor skip work class 	 Lemmatized word:travel far andor skip work class
# Original Word: travel far andor skip work class 	 Lemmatized word:travel far andor skip work class
# Original Word: travel far andor skip work class 	 Lemmatized word:travel far andor skip work class
# Original Word: prefer vaccine 	 Lemmatized word:prefer vaccine
# Original Word: vaccine state 	 Lemmatized word:vaccine state
# Original Word: testing 	 Lemmatized word:testing
# Original Word: testing 	 Lemmatized word:testing
# Original Word: Nothing 	 Lemmatized word:Nothing
# Original Word: Nothing 	 Lemmatized word:Nothing
# Original Word: lack options not times available work classes 	 Lemmatized word:lack options not times available work classes
# Original Word: lack options not times available work classes 	 Lemmatized word:lack options not times available work classes
# Original Word: think 	 Lemmatized word:think
# Original Word: optional 	 Lemmatized word:optional
# Original Word: optional 	 Lemmatized word:optional
# Original Word: vaccinate covid 	 Lemmatized word:vaccinate covid
# Original Word: travel far distance 	 Lemmatized word:travel far distance
# Original Word: travel far distance 	 Lemmatized word:travel far distance
# Original Word: Transportation 	 Lemmatized word:Transportation
# Original Word: Confusion rules groups lack confidence safety distribution location 	 Lemmatized word:Confusion rules groups lack confidence safety distribution location
# Original Word: Confusion rules groups lack confidence safety distribution location 	 Lemmatized word:Confusion rules groups lack confidence safety distribution location
# Original Word: gets vaccine need wear masks social distance want vaccine 	 Lemmatized word:gets vaccine need wear masks social distance want vaccine
# Original Word: fact vaccine new flu shot  effective years developing flu shots knowing ample time test vaccine drugs health conditions saying deaths occur people COVID vaccination greater good humanity 	 Lemmatized word:fact vaccine new flu shot  effective years developing flu shots knowing ample time test vaccine drugs health conditions saying deaths occur people COVID vaccination greater good humanity
# Original Word: narrow range appointment times 	 Lemmatized word:narrow range appointment times
res  feet apart nonsense need it Thats pretty irrelevant theres vaccine 	 Lemmatized word:theres  feet apart nonsense need it Thats pretty irrelevant theres vaccine
# Original Word: theres  feet apart nonsense need it Thats pretty irrelevant theres vaccine 	 Lemmatized word:theres  feet apart nonsense need it Thats pretty irrelevant theres vaccine
# Original Word: giving  days choice 	 Lemmatized word:giving  days choice
# Original Word: giving  days choice 	 Lemmatized word:giving  days choice
# Original Word: giving  days choice 	 Lemmatized word:giving  days choice
# Original Word: giving  days choice 	 Lemmatized word:giving  days choice
# Original Word: Offered far away campus 	 Lemmatized word:Offered far away campus
# Original Word: easily accessible location 	 Lemmatized word:easily accessible location
# Original Word: Id afraid getting sick sick shots like that like flu vaccine 	 Lemmatized word:Id afraid getting sick sick shots like that like flu vaccine
# Original Word: Id afraid getting sick sick shots like that like flu vaccine 	 Lemmatized word:Id afraid getting sick sick shots like that like flu vaccine
# Original Word: Id afraid getting sick sick shots like that like flu vaccine 	 Lemmatized word:Id afraid getting sick sick shots like that like flu vaccine
# Original Word: Inconvenient times 	 Lemmatized word:Inconvenient times
# Original Word: cant imagine 	 Lemmatized word:cant imagine
# Original Word: inability choose scheduling appointment 	 Lemmatized word:inability choose scheduling appointment
# Original Word: location campus car reach site 	 Lemmatized word:location campus car reach site
# Original Word: location campus car reach site 	 Lemmatized word:location campus car reach site
# Original Word: location campus car reach site 	 Lemmatized word:location campus car reach site
# Original Word:  	 Lemmatized word:
# Original Word: lot people getting 	 Lemmatized word:lot people getting
# Original Word: offcampus vaccine stand line vaccine no appointments like COVID testing 	 Lemmatized word:offcampus vaccine stand line vaccine no appointments like COVID testing
# Original Word: assigned random time 	 Lemmatized word:assigned random time
# Original Word: assigned random time 	 Lemmatized word:assigned random time
# Original Word: Work class 	 Lemmatized word:Work class
# Original Word: Nothing it 	 Lemmatized word:Nothing it
# Original Word: far away 	 Lemmatized word:far away
# Original Word: far away 	 Lemmatized word:far away
# Original Word: trusting especially company making harmful products cause cancer 	 Lemmatized word:trusting especially company making harmful products cause cancer
# Original Word: Lack time school work 	 Lemmatized word:Lack time school work
# Original Word: busy schedule worried effects 	 Lemmatized word:busy schedule worried effects
# Original Word: scheduled vaccine 	 Lemmatized word:scheduled vaccine
# Original Word: School 	 Lemmatized word:School
# Original Word: School 	 Lemmatized word:School
# Original Word: Phase  nonessential preexisting conditionsmorbidities person eligible vaccine based phased rollout 	 Lemmatized word:Phase  nonessential preexisting conditionsmorbidities person eligible vaccine based phased rollout
# Original Word: Lack supply 	 Lemmatized word:Lack supply
# Original Word: Lack supply 	 Lemmatized word:Lack supply
# Original Word: Availability 	 Lemmatized word:Availability
# Original Word: Availability 	 Lemmatized word:Availability
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word: stay Boone second dose 	 Lemmatized word:stay Boone second dose
# Original Word: stay Boone second dose 	 Lemmatized word:stay Boone second dose
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word: leaving work 	 Lemmatized word:leaving work
# Original Word: leaving work 	 Lemmatized word:leaving work
# Original Word: campus 	 Lemmatized word:campus
# Original Word: availability 	 Lemmatized word:availability
# Original Word: Im getting cant force too 	 Lemmatized word:Im getting cant force too
# Original Word: Im getting cant force too 	 Lemmatized word:Im getting cant force too
# Original Word: Im getting cant force too 	 Lemmatized word:Im getting cant force too
# Original Word: date time available vaccination 	 Lemmatized word:date time available vaccination
# Original Word: date time available vaccination 	 Lemmatized word:date time available vaccination
# Original Word: knowing effect body 	 Lemmatized word:knowing effect body
# Original Word: knowing effect body 	 Lemmatized word:knowing effect body
# Original Word: knowing effect body 	 Lemmatized word:knowing effect body
# Original Word: Transportation 	 Lemmatized word:Transportation
# Original Word: Transportation 	 Lemmatized word:Transportation
# Original Word: Transportation 	 Lemmatized word:Transportation
# Original Word: religious beliefs 	 Lemmatized word:religious beliefs
# Original Word: Classes 	 Lemmatized word:Classes
# Original Word: hearing available long lines hard time appointment etc 	 Lemmatized word:hearing available long lines hard time appointment etc
# Original Word: risks effects 	 Lemmatized word:risks effects
# Original Word: allergic itpeople medical issues needed moretime work 	 Lemmatized word:allergic itpeople medical issues needed moretime work
# Original Word: allergic itpeople medical issues needed moretime work 	 Lemmatized word:allergic itpeople medical issues needed moretime work
# Original Word: allergic itpeople medical issues needed moretime work 	 Lemmatized word:allergic itpeople medical issues needed moretime work
# Original Word: allergic itpeople medical issues needed moretime work 	 Lemmatized word:allergic itpeople medical issues needed moretime work
# Original Word: allergic itpeople medical issues needed moretime work 	 Lemmatized word:allergic itpeople medical issues needed moretime work
# Original Word: allergic itpeople medical issues needed moretime work 	 Lemmatized word:allergic itpeople medical issues needed moretime work
# Original Word: sure 	 Lemmatized word:sure
# Original Word: sure 	 Lemmatized word:sure
# Original Word: sure 	 Lemmatized word:sure
# Original Word: Distance 	 Lemmatized word:Distance
# Original Word: campus dont car 	 Lemmatized word:campus dont car
# Original Word: location campus limited hours class meetings days 	 Lemmatized word:location campus limited hours class meetings days
# Original Word: location campus limited hours class meetings days 	 Lemmatized word:location campus limited hours class meetings days
# Original Word:  	 Lemmatized word:
# Original Word: knowing receiving said vaccine 	 Lemmatized word:knowing receiving said vaccine
# Original Word: knowing receiving said vaccine 	 Lemmatized word:knowing receiving said vaccine
# Original Word: drivewait line 	 Lemmatized word:drivewait line
# Original Word: familys opinions 	 Lemmatized word:familys opinions
# Original Word:  	 Lemmatized word:
# Original Word: chances bad reaction 	 Lemmatized word:chances bad reaction
# Original Word: chances bad reaction 	 Lemmatized word:chances bad reaction
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word
# Original Word: Long wait times 	 Lemmatized word:Long wait times
# Original Word: Long wait times 	 Lemmatized word:Long wait times
# Original Word: Long wait times 	 Lemmatized word:Long wait times
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word: reports effects 	 Lemmatized word:reports effects
# Original Word: reports effects 	 Lemmatized word:reports effects
# Original Word: reports effects 	 Lemmatized word:reports effects
# Original Word: vaccines ineffective system receiving vaccines 	 Lemmatized word:vaccines ineffective system receiving vaccines
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word: Availability 	 Lemmatized word:Availability
# Original Word: Availability 	 Lemmatized word:Availability
# Original Word: Price 	 Lemmatized word:Price
# Original Word: Strict hours sleeping disorders waking early morning struggle 	 Lemmatized word:Strict hours sleeping disorders waking early morning struggle
# Original Word: Long wait times Scheduling 	 Lemmatized word:Long wait times Scheduling
# Original Word: wont vaccine 	 Lemmatized word:wont vaccine
# Original Word: wont vaccine 	 Lemmatized word:wont vaccine
# Original Word: wont vaccine 	 Lemmatized word:wont vaccine
# Original Word: wont vaccine 	 Lemmatized word:wont vaccine
# Original Word: wont vaccine 	 Lemmatized word:wont vaccine
# Original Word: wont vaccine 	 Lemmatized word:wont vaccine
# Original Word: wont vaccine 	 Lemmatized word:wont vaccine
# Original Word: wont vaccine 	 Lemmatized word:wont vaccine
# Original Word: wont vaccine 	 Lemmatized word:wont vaccine
# Original Word: money wise people want 	 Lemmatized word:money wise people want
# Original Word: money wise people want 	 Lemmatized word:money wise people want
# Original Word: money wise people want 	 Lemmatized word:money wise people want
# Original Word: money wise people want 	 Lemmatized word:money wise people want
# Original Word: money wise people want 	 Lemmatized word:money wise people want
# Original Word: money wise people want 	 Lemmatized word:money wise people want
# Original Word: money wise people want 	 Lemmatized word:money wise people want
# Original Word: money wise people want 	 Lemmatized word:money wise people want
# Original Word: money wise people want 	 Lemmatized word:money wise people want
# Original Word: money wise people want 	 Lemmatized word:money wise people want
# Original Word: money wise people want 	 Lemmatized word:money wise people want
# Original Word: money wise people want 	 Lemmatized word:money wise people want
# Original Word: money wise people want 	 Lemmatized word:money wise people want
# Original Word: money wise people want 	 Lemmatized word:money wise people want
# Original Word: personal time possible affects 	 Lemmatized word:personal time possible affects
# Original Word: personal time possible affects 	 Lemmatized word:personal time possible affects
# Original Word: personal time possible affects 	 Lemmatized word:personal time possible affects
# Original Word: personal time possible affects 	 Lemmatized word:personal time possible affects
# Original Word: personal time possible affects 	 Lemmatized word:personal time possible affects
# Original Word: personal time possible affects 	 Lemmatized word:personal time possible affects
# Original Word: personal time possible affects 	 Lemmatized word:personal time possible affects
# Original Word: run 	 Lemmatized word:run
# Original Word: run 	 Lemmatized word:run
# Original Word: dose 	 Lemmatized word:dose
# Original Word: Schedule 	 Lemmatized word:Schedule
# Original Word: come serve lines 	 Lemmatized word:come serve lines
# Original Word: come serve lines 	 Lemmatized word:come serve lines
# Original Word: Fees Vaccinations 	 Lemmatized word:Fees Vaccinations
# Original Word: vaccinated 	 Lemmatized word:vaccinated
# Original Word: vaccinated 	 Lemmatized word:vaccinated
# Original Word: Deciding wait till home probably home summer came time second dose 	 Lemmatized word:Deciding wait till home probably home summer came time second dose
# Original Word: Deciding wait till home probably home summer came time second dose 	 Lemmatized word:Deciding wait till home probably home summer came time second dose
# Original Word: Deciding wait till home probably home summer came time second dose 	 Lemmatized word:Deciding wait till home probably home summer came time second dose
# Original Word: Deciding wait till home probably home summer came time second dose 	 Lemmatized word:Deciding wait till home probably home summer came time second dose
# Original Word: Deciding wait till home probably home summer came time second dose 	 Lemmatized word:Deciding wait till home probably home summer came time second dose
# Original Word: wouldnt difficult wouldnt want forced university its personal choice 	 Lemmatized word:wouldnt difficult wouldnt want forced university its personal choice
# Original Word: Making sign difficult 	 Lemmatized word:Making sign difficult
# Original Word: Making sign difficult 	 Lemmatized word:Making sign difficult
# Original Word: Making sign difficult 	 Lemmatized word:Making sign difficult
# Original Word: Long waits time slots interfere classes 	 Lemmatized word:Long waits time slots interfere classes
# Original Word: Long waits time slots interfere classes 	 Lemmatized word:Long waits time slots interfere classes
# Original Word: goes core belief enforce terrifying thought organization bodies unknown risk futurereactions especially built immunity contracting virus makes worried difficult 	 Lemmatized word:goes core belief enforce terrifying thought organization bodies unknown risk futurereactions especially built immunity contracting virus makes worried difficult
# Original Word: goes core belief enforce terrifying thought organization bodies unknown risk futurereactions especially built immunity contracting virus makes worried difficult 	 Lemmatized word:goes core belief enforce terrifying thought organization bodies unknown risk futurereactions especially built immunity contracting virus makes worried difficult
# Original Word: goes core belief enforce terrifying thought organization bodies unknown risk futurereactions especially built immunity contracting virus makes worried difficult 	 Lemmatized word:goes core belief enforce terrifying thought organization bodies unknown risk futurereactions especially built immunity contracting virus makes worried difficult
# Original Word: goes core belief enforce terrifying thought organization bodies unknown risk futurereactions especially built immunity contracting virus makes worried difficult 	 Lemmatized word:goes core belief enforce terrifying thought organization bodies unknown risk futurereactions especially built immunity contracting virus makes worried difficult
# Original Word: couldnt work 	 Lemmatized word:couldnt work
# Original Word: Im sure 	 Lemmatized word:Im sure
# Original Word: Im sure 	 Lemmatized word:Im sure
# Original Word: long distance 	 Lemmatized word:long distance
# Original Word: long distance 	 Lemmatized word:long distance
# Original Word: long distance 	 Lemmatized word:long distance
# Original Word: long distance 	 Lemmatized word:long distance
# Original Word: long distance 	 Lemmatized word:long distance
# Original Word: giving far live like blowing rock 	 Lemmatized word:giving far live like blowing rock
# Original Word: finding appointment fits schedule 	 Lemmatized word:finding appointment fits schedule
# Original Word: finding appointment fits schedule 	 Lemmatized word:finding appointment fits schedule
# Original Word: Health risks 	 Lemmatized word:Health risks
# Original Word: wait line Appointment 	 Lemmatized word:wait line Appointment
# Original Word: Hospital visit 	 Lemmatized word:Hospital visit
# Original Word: depending day time available 	 Lemmatized word:depending day time available
# Original Word: knowing effects 	 Lemmatized word:knowing effects
# Original Word: knowing effects 	 Lemmatized word:knowing effects
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word: needlephobia able 	 Lemmatized word:needlephobia able
# Original Word: teacher dying app state aborted fetal cells vaccine 	 Lemmatized word:teacher dying app state aborted fetal cells vaccine
# Original Word: teacher dying app state aborted fetal cells vaccine 	 Lemmatized word:teacher dying app state aborted fetal cells vaccine
# Original Word: Transportation 	 Lemmatized word:Transportation
# Original Word: Transportation 	 Lemmatized word:Transportation
# Original Word: confusing appointment making process 	 Lemmatized word:confusing appointment making process
# Original Word: time schedules difficult fit classes 	 Lemmatized word:time schedules difficult fit classes
# Original Word: time schedules difficult fit classes 	 Lemmatized word:time schedules difficult fit classes
# Original Word: Inconvenient location able choose timedate 	 Lemmatized word:Inconvenient location able choose timedate
# Original Word: vaccination sites far away 	 Lemmatized word:vaccination sites far away
# Original Word: Long LinesWaiting Periods 	 Lemmatized word:Long LinesWaiting Periods
# Original Word: Long LinesWaiting Periods 	 Lemmatized word:Long LinesWaiting Periods
# Original Word: Long LinesWaiting Periods 	 Lemmatized word:Long LinesWaiting Periods
# Original Word: want it 	 Lemmatized word:want it
# Original Word: want it 	 Lemmatized word:want it
# Original Word: want it 	 Lemmatized word:want it
# Original Word: want it 	 Lemmatized word:want it
# Original Word: want it 	 Lemmatized word:want it
# Original Word: want it 	 Lemmatized word:want it
# Original Word: want it 	 Lemmatized word:want it
# Original Word: want it 	 Lemmatized word:want it
# Original Word: want it 	 Lemmatized word:want it
# Original Word: want it 	 Lemmatized word:want it
# Original Word: want it 	 Lemmatized word:want it
# Original Word: want it 	 Lemmatized word:want it
# Original Word: thought negative effects health 	 Lemmatized word:thought negative effects health
# Original Word: thought negative effects health 	 Lemmatized word:thought negative effects health
# Original Word: advertising 	 Lemmatized word:advertising
# Original Word: advertising 	 Lemmatized word:advertising
# Original Word: advertising 	 Lemmatized word:advertising
# Original Word: advertising 	 Lemmatized word:advertising
# Original Word: advertising 	 Lemmatized word:advertising
# Original Word: advertising 	 Lemmatized word:advertising
# Original Word: advertising 	 Lemmatized word:advertising
# Original Word: advertising 	 Lemmatized word:advertising
# Original Word: advertising 	 Lemmatized word:advertising
# Original Word: advertising 	 Lemmatized word:advertising
# Original Word: advertising 	 Lemmatized word:advertising
# Original Word: advertising 	 Lemmatized word:advertising
# Original Word: lack transportationconflicting schedule primary worries 	 Lemmatized word:lack transportationconflicting schedule primary worries
# Original Word: lack transportationconflicting schedule primary worries 	 Lemmatized word:lack transportationconflicting schedule primary worries
# Original Word: lack transportationconflicting schedule primary worries 	 Lemmatized word:lack transportationconflicting schedule primary worries
# Original Word: lack transportationconflicting schedule primary worries 	 Lemmatized word:lack transportationconflicting schedule primary worries
# Original Word: lack transportationconflicting schedule primary worries 	 Lemmatized word:lack transportationconflicting schedule primary worries
# Original Word: lack transportationconflicting schedule primary worries 	 Lemmatized word:lack transportationconflicting schedule primary worries
# Original Word: lack transportationconflicting schedule primary worries 	 Lemmatized word:lack transportationconflicting schedule primary worries
# Original Word: lack transportationconflicting schedule primary worries 	 Lemmatized word:lack transportationconflicting schedule primary worries
# Original Word: email saying group able vaccine its group eligible 	 Lemmatized word:email saying group able vaccine its group eligible
# Original Word: dont completely understand aspects Im sure safe 	 Lemmatized word:dont completely understand aspects Im sure safe
# Original Word: dont completely understand aspects Im sure safe 	 Lemmatized word:dont completely understand aspects Im sure safe
# Original Word: dont completely understand aspects Im sure safe 	 Lemmatized word:dont completely understand aspects Im sure safe
# Original Word: Johnson  Johnson vaccine 	 Lemmatized word:Johnson  Johnson vaccine
# Original Word: Johnson  Johnson vaccine 	 Lemmatized word:Johnson  Johnson vaccine
# Original Word: Johnson  Johnson vaccine 	 Lemmatized word:Johnson  Johnson vaccine
# Original Word: Johnson  Johnson vaccine 	 Lemmatized word:Johnson  Johnson vaccine
# Original Word: new 	 Lemmatized word:new
# Original Word: new 	 Lemmatized word:new
# Original Word: told cant tomorrow 	 Lemmatized word:told cant tomorrow
# Original Word: Lack knowing effects 	 Lemmatized word:Lack knowing effects
# Original Word: Lack knowing effects 	 Lemmatized word:Lack knowing effects
# Original Word: Boone 	 Lemmatized word:Boone
# Original Word: effects pertain vaccine 	 Lemmatized word:effects pertain vaccine
# Original Word: effects pertain vaccine 	 Lemmatized word:effects pertain vaccine
# Original Word: effects pertain vaccine 	 Lemmatized word:effects pertain vaccine
# Original Word: effects pertain vaccine 	 Lemmatized word:effects pertain vaccine
# Original Word: effects pertain vaccine 	 Lemmatized word:effects pertain vaccine
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word: times April difficult me 	 Lemmatized word:times April difficult me
# Original Word: allergic tree nuts time person watch incase reaction 	 Lemmatized word:allergic tree nuts time person watch incase reaction
# Original Word: Complications current schedule 	 Lemmatized word:Complications current schedule
# Original Word: Complications current schedule 	 Lemmatized word:Complications current schedule
# Original Word: Complications current schedule 	 Lemmatized word:Complications current schedule
# Original Word: vaccines offered oncampus 	 Lemmatized word:vaccines offered oncampus
# Original Word: vaccines offered oncampus 	 Lemmatized word:vaccines offered oncampus
# Original Word: vaccines offered oncampus 	 Lemmatized word:vaccines offered oncampus
# Original Word: vaccines offered oncampus 	 Lemmatized word:vaccines offered oncampus
# Original Word: vaccines offered oncampus 	 Lemmatized word:vaccines offered oncampus
# Original Word: vaccines offered oncampus 	 Lemmatized word:vaccines offered oncampus

# %%
for i in dataset["Obstacles"]:
    print("Original Word: {} \t Lemmatized word:{}".format(i, lemmatizer.lemmatize(i, pos='v')))
# Out:
# Original Word: hour half away campus 	 Lemmatized word:hour half away campus
# Original Word: inability transportation vaccination sites 	 Lemmatized word:inability transportation vaccination sites
# Original Word: Scheduling 	 Lemmatized word:Scheduling
# Original Word: Scheduling 	 Lemmatized word:Scheduling
# Original Word: Scheduling 	 Lemmatized word:Scheduling
# Original Word: Scheduling 	 Lemmatized word:Scheduling
# Original Word: personal phobia needles biggest hurdle 	 Lemmatized word:personal phobia needles biggest hurdle
# Original Word: personal phobia needles biggest hurdle 	 Lemmatized word:personal phobia needles biggest hurdle
# Original Word: Lack communication appointment availability 	 Lemmatized word:Lack communication appointment availability
# Original Word: Lack communication appointment availability 	 Lemmatized word:Lack communication appointment availability
# Original Word: Lack communication appointment availability 	 Lemmatized word:Lack communication appointment availability
# Original Word: Lack communication appointment availability 	 Lemmatized word:Lack communication appointment availability
# Original Word: Lack communication appointment availability 	 Lemmatized word:Lack communication appointment availability
# Original Word: hours limited 	 Lemmatized word:hours limited
# Original Word: hours limited 	 Lemmatized word:hours limited
# Original Word: tight time slot 	 Lemmatized word:tight time slot
# Original Word: tight time slot 	 Lemmatized word:tight time slot
# Original Word: Its money its research prove safety effectiveness 	 Lemmatized word:Its money its research prove safety effectiveness
# Original Word: Its money its research prove safety effectiveness 	 Lemmatized word:Its money its research prove safety effectiveness
# Original Word: Its money its research prove safety effectiveness 	 Lemmatized word:Its money its research prove safety effectiveness
# Original Word: Availability appetizers 	 Lemmatized word:Availability appetizers
# Original Word: Availability appetizers 	 Lemmatized word:Availability appetizers
# Original Word: Difficult access 	 Lemmatized word:Difficult access
# Original Word: physically inaccessible 	 Lemmatized word:physically inaccessible
# Original Word: physically inaccessible 	 Lemmatized word:physically inaccessible
# Original Word: physically inaccessible 	 Lemmatized word:physically inaccessible
# Original Word: physically inaccessible 	 Lemmatized word:physically inaccessible
# Original Word: physically inaccessible 	 Lemmatized word:physically inaccessible
# Original Word: practice meets sickness 	 Lemmatized word:practice meets sickness
# Original Word: practice meets sickness 	 Lemmatized word:practice meets sickness
# Original Word: practice meets sickness 	 Lemmatized word:practice meets sickness
# Original Word: practice meets sickness 	 Lemmatized word:practice meets sickness
# Original Word: sure 	 Lemmatized word:sure
# Original Word:  	 Lemmatized word:
# Original Word: week school 	 Lemmatized word:week school
# Original Word: Boone doable preferred 	 Lemmatized word:Boone doable preferred
# Original Word: Boone doable preferred 	 Lemmatized word:Boone doable preferred
# Original Word: location outside Boone 	 Lemmatized word:location outside Boone
# Original Word: location outside Boone 	 Lemmatized word:location outside Boone
# Original Word: Scheduling transportation 	 Lemmatized word:Scheduling transportation
# Original Word: Farther home 	 Lemmatized word:Farther home
# Original Word: Farther home 	 Lemmatized word:Farther home
# Original Word: Farther home 	 Lemmatized word:Farther home
# Original Word: Farther home 	 Lemmatized word:Farther home
# Original Word: Farther home 	 Lemmatized word:Farther home
# Original Word: Farther home 	 Lemmatized word:Farther home
# Original Word: Weird time slots 	 Lemmatized word:Weird time slots
# Original Word: High demand 	 Lemmatized word:High demand
# Original Word: High demand 	 Lemmatized word:High demand
# Original Word: High demand 	 Lemmatized word:High demand
# Original Word: High demand 	 Lemmatized word:High demand
# Original Word: Transportation possible issue 	 Lemmatized word:Transportation possible issue
# Original Word: Na 	 Lemmatized word:Na
# Original Word: Na 	 Lemmatized word:Na
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word: drive 	 Lemmatized word:drive
# Original Word: Lack information vaccine 	 Lemmatized word:Lack information vaccine
# Original Word: need information 	 Lemmatized word:need information
# Original Word: need information 	 Lemmatized word:need information
# Original Word: Hours compatible class schedule 	 Lemmatized word:Hours compatible class schedule
# Original Word: available Charlotte 	 Lemmatized word:available Charlotte
# Original Word: Idk 	 Lemmatized word:Idk
# Original Word: Idk 	 Lemmatized word:Idk
# Original Word: Nothing its available me 	 Lemmatized word:Nothing its available me
# Original Word: drive far distance order receive it 	 Lemmatized word:drive far distance order receive it
# Original Word: drive far distance order receive it 	 Lemmatized word:drive far distance order receive it
# Original Word: reason location hours away cant time 	 Lemmatized word:reason location hours away cant time
# Original Word: Lack transportation 	 Lemmatized word:Lack transportation
# Original Word: Lack transportation 	 Lemmatized word:Lack transportation
# Original Word: Lack transportation 	 Lemmatized word:Lack transportation
# Original Word: body vaccines well Ie fainting consistently dose received 	 Lemmatized word:body vaccines well Ie fainting consistently dose received
# Original Word: body vaccines well Ie fainting consistently dose received 	 Lemmatized word:body vaccines well Ie fainting consistently dose received
# Original Word: Long wait 	 Lemmatized word:Long wait
# Original Word: Long wait 	 Lemmatized word:Long wait
# Original
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word: travel receive 	 Lemmatized word:travel receive
# Original Word: forth home school frequently vaccine date fall day campus 	 Lemmatized word:forth home school frequently vaccine date fall day campus
# Original Word: Limited hours far away 	 Lemmatized word:Limited hours far away
# Original Word: Timing offered midterm week 	 Lemmatized word:Timing offered midterm week
# Original Word: Timing offered midterm week 	 Lemmatized word:Timing offered midterm week
# Original Word: fewer locations available appointment times lack information howwhere appointment 	 Lemmatized word:fewer locations available appointment times lack information howwhere appointment
# Original Word: fewer locations available appointment times lack information howwhere appointment 	 Lemmatized word:fewer locations available appointment times lack information howwhere appointment
# Original Word: specific time time class time day practicum difficult rearrange vaccine 	 Lemmatized word:specific time time class time day practicum difficult rearrange vaccine
# Original Word: appointment 	 Lemmatized word:appointment
# Original Word: wouldnt 	 Lemmatized word:wouldnt
# Original Word: wouldnt 	 Lemmatized word:wouldnt
# Original Word: vaccine available near 	 Lemmatized word:vaccine available near
# Original Word: Knowing high rate severe fatal effects 	 Lemmatized word:Knowing high rate severe fatal effects
# Original Word:  	 Lemmatized word:
# Original Word: time offered long wait line Waiting lines mask social distancing freaks feels dystopian 	 Lemmatized word:time offered long wait line Waiting lines mask social distancing freaks feels dystopian
# Original Word: Long wait times 	 Lemmatized word:Long wait times
# Original Word: Long wait times 	 Lemmatized word:Long wait times
# Original Word: seeing people react 	 Lemmatized word:seeing people react
# Original Word: seeing people react 	 Lemmatized word:seeing people react
# Original Word: Scheduling issues 	 Lemmatized word:Scheduling issues
# Original Word: Failed efficacy increased reactions 	 Lemmatized word:Failed efficacy increased reactions
# Original Word: Finding free moment it 	 Lemmatized word:Finding free moment it
# Original Word: Finding free moment it 	 Lemmatized word:Finding free moment it
# Original Word: Aggressivepushy advertising 	 Lemmatized word:Aggressivepushy advertising
# Original Word: Aggressivepushy advertising 	 Lemmatized word:Aggressivepushy advertising
# Original Word: Aggressivepushy advertising 	 Lemmatized word:Aggressivepushy advertising
# Original Word: multiple allergies life threatening 	 Lemmatized word:multiple allergies life threatening
# Original Word: Requirements 	 Lemmatized word:Requirements
# Original Word: effects drive somewhere inconvenience 	 Lemmatized word:effects drive somewhere inconvenience
# Original Word: effects drive somewhere inconvenience 	 Lemmatized word:effects drive somewhere inconvenience
# Original Word: effects drive somewhere inconvenience 	 Lemmatized word:effects drive somewhere inconvenience
# Original Word: waiting crowding 	 Lemmatized word:waiting crowding
# Original Word: waiting crowding 	 Lemmatized word:waiting crowding
# Original Word: waiting crowding 	 Lemmatized word:waiting crowding
# Original Word: waiting crowding 	 Lemmatized word:waiting crowding
# Original Word: waiting crowding 	 Lemmatized word:waiting crowding
# Original Word:  	 Lemmatized word:
# Original Word: dont want 	 Lemmatized word:dont want
# Original Word: dont want 	 Lemmatized word:dont want
# Original Word: far away located 	 Lemmatized word:far away located
# Original Word: certain time 	 Lemmatized word:certain time
# Original Word: certain time 	 Lemmatized word:certain time
# Original Word: time 	 Lemmatized word:time
# Original Word: time 	 Lemmatized word:time
# Original Word: Overload people signing similar times 	 Lemmatized word:Overload people signing similar times
# Original Word: advertising competitive time slots 	 Lemmatized word:advertising competitive time slots
# Original Word: Getting appointment 	 Lemmatized word:Getting appointment
# Original Word: Anxiety 	 Lemmatized word:Anxiety
# Original Word: research time up 	 Lemmatized word:research time up
# Original Word: knowing long term effects 	 Lemmatized word:knowing long term effects
# Original Word: knowing long term effects 	 Lemmatized word:knowing long term effects
# Original Word: limited times 	 Lemmatized word:limited times
# Original Word: uninformed unclear procedure schedule appointment 	 Lemmatized word:uninformed unclear procedure schedule appointment
# Original Word: unwillingness vaccine 	 Lemmatized word:unwillingness vaccine
# Original Word: fear bad reaction 	 Lemmatized word:fear bad reaction
# Original Word: Short hours working schedule 	 Lemmatized word:Short hours working schedule
# Original Word: worried sideeffects actual virus 	 Lemmatized word:worried sideeffects actual virus
# Original Word: Making available times common person works 	 Lemmatized word:Making available times common person works
# Original Word: getting notification 	 Lemmatized word:getting notification
# Original Word: getting notification 	 Lemmatized word:getting notification
# Original Word: getting notification 	 Lemmatized word:getting notification
# Original Word: schedule appointment 	 Lemmatized word:schedule appointment
# Original Word: fact COVID going eventually endemic numbers dramatically fall coming days mutate booster shots year Right healthy individual believes need me 	 Lemmatized word:fact COVID going eventually endemic numbers dramatically fall coming days mutate booster shots year Right healthy individual believes need me
# Original Word: fact COVID going eventually endemic numbers dramatically fall coming days mutate booster shots year Right healthy individual believes need me 	 Lemmatized word:fact COVID going eventually endemic numbers dramatically fall coming days mutate booster shots year Right healthy individual believes need me
# Original Word: fact COVID going eventually endemic numbers dramatically fall coming days mutate booster shots year Right healthy individual believes need me 	 Lemmatized word:fact COVID going eventually endemic numbers dramatically fall coming days mutate booster shots year Right healthy individual believes need me
# Original Word: reason above shot 	 Lemmatized word:reason above shot
# Original Word: given campus 	 Lemmatized word:given campus
# Original Word: knowing eligible inability appointment 	 Lemmatized word:knowing eligible inability appointment
# Original Word: knowing eligible inability appointment 	 Lemmatized word:knowing eligible inability appointment
# Original Word: knowing eligible inability appointment 	 Lemmatized word:knowing eligible inability appointment
# Original Word: knowing eligible inability appointment 	 Lemmatized word:knowing eligible inability appointment
# Original Word: knowing eligible inability appointment 	 Lemmatized word:knowing eligible inability appointment
# Original Word: Getting waiting list goes ahead shot happening counties state  year old mother Boone actually vaccine lives Henderson County waiting list vaccination thousand people appointments shot ahead thousands waiting list 	 Lemmatized word:Getting waiting list goes ahead shot happening counties state  year old mother Boone actually vaccine lives Henderson County waiting list vaccination thousand people appointments shot ahead thousands waiting list
# Original Word: Getting waiting list goes ahead shot happening counties state  year old mother Boone actually vaccine lives Henderson County waiting list vaccination thousand people appointments shot ahead thousands waiting list 	 Lemmatized word:Getting waiting list goes ahead shot happening counties state  year old mother Boone actually vaccine lives Henderson County waiting list vaccination thousand people appointments shot ahead thousands waiting list
# Original Word: Nothing 	 Lemmatized word:Nothing
# Original Word: idea forced makes difficult me think fair force vaccine unknown effects people Flu Measles HPV vaccines seen effects years Covid vaccine months 	 Lemmatized word:idea forced makes difficult me think fair force vaccine unknown effects people Flu Measles HPV vaccines seen effects years Covid vaccine months
# Original Word: required essential worker caretaker as neither 	 Lemmatized word:required essential worker caretaker as neither
# Original Word: required essential worker caretaker as neither 	 Lemmatized word:required essential worker caretaker as neither
# Original Word: required essential worker caretaker as neither 	 Lemmatized word:required essential worker caretaker as neither
# Original Word: Nothing refuse it 	 Lemmatized word:Nothing refuse it
# Original Word: insane wait ie like  hours 	 Lemmatized word:insane wait ie like  hours
# Original Word: insane wait ie like  hours 	 Lemmatized word:insane wait ie like  hours
# Original Word: far away 	 Lemmatized word:far away
# Original Word: Time management 	 Lemmatized word:Time management
# Original Word: Time management 	 Lemmatized word:Time management
# Original Word: Time management 	 Lemmatized word:Time management
# Original Word: travel far andor skip work class 	 Lemmatized word:travel far andor skip work class
# Original Word: travel far andor skip work class 	 Lemmatized word:travel far andor skip work class
# Original Word: travel far andor skip work class 	 Lemmatized word:travel far andor skip work class
# Original Word: travel far andor skip work class 	 Lemmatized word:travel far andor skip work class
# Original Word: travel far andor skip work class 	 Lemmatized word:travel far andor skip work class
# Original Word: prefer vaccine 	 Lemmatized word:prefer vaccine
# Original Word: vaccine state 	 Lemmatized word:vaccine state
# Original Word: testing 	 Lemmatized word:test
# Original Word: testing 	 Lemmatized word:test
# Original Word: Nothing 	 Lemmatized word:Nothing
# Original Word: Nothing 	 Lemmatized word:Nothing
# Original Word: lack options not times available work classes 	 Lemmatized word:lack options not times available work classes
# Original Word: lack options not times available work classes 	 Lemmatized word:lack options not times available work classes
# Original Word: think 	 Lemmatized word:think
# Original Word: optional 	 Lemmatized word:optional
# Original Word: optional 	 Lemmatized word:optional
# Original Word: vaccinate covid 	 Lemmatized word:vaccinate covid
# Original Word: travel far distance 	 Lemmatized word:travel far distance
# Original Word: travel far distance 	 Lemmatized word:travel far distance
# Original Word: Transportation 	 Lemmatized word:Transportation
# Original Word: Confusion rules groups lack confidence safety distribution location 	 Lemmatized word:Confusion rules groups lack confidence safety distribution location
# Original Word: Confusion rules groups lack confidence safety distribution location 	 Lemmatized word:Confusion rules groups lack confidence safety distribution location
# Original Word: gets vaccine need wear masks social distance want vaccine 	 Lemmatized word:gets vaccine need wear masks social distance want vaccine
# Original Word: fact vaccine new flu shot  effective years developing flu shots knowing ample time test vaccine drugs health conditions saying deaths occur people COVID vaccination greater good humanity 	 Lemmatized word:fact vaccine new flu shot  effective years developing flu shots knowing ample time test vaccine drugs health conditions saying deaths occur people COVID vaccination greater good humanity
# Original Word: narrow range appointment times 	 Lemmatized word:narrow range appointment times
# Original Word: narrow range appointment times 	 Lemmatized word:narrow range appointment times
res  feet apart nonsense need it Thats pretty irrelevant theres vaccine 	 Lemmatized word:theres  feet apart nonsense need it Thats pretty irrelevant theres vaccine
# Original Word: theres  feet apart nonsense need it Thats pretty irrelevant theres vaccine 	 Lemmatized word:theres  feet apart nonsense need it Thats pretty irrelevant theres vaccine
# Original Word: giving  days choice 	 Lemmatized word:giving  days choice
# Original Word: giving  days choice 	 Lemmatized word:giving  days choice
# Original Word: giving  days choice 	 Lemmatized word:giving  days choice
# Original Word: giving  days choice 	 Lemmatized word:giving  days choice
# Original Word: Offered far away campus 	 Lemmatized word:Offered far away campus
# Original Word: easily accessible location 	 Lemmatized word:easily accessible location
# Original Word: Id afraid getting sick sick shots like that like flu vaccine 	 Lemmatized word:Id afraid getting sick sick shots like that like flu vaccine
# Original Word: Id afraid getting sick sick shots like that like flu vaccine 	 Lemmatized word:Id afraid getting sick sick shots like that like flu vaccine
# Original Word: Id afraid getting sick sick shots like that like flu vaccine 	 Lemmatized word:Id afraid getting sick sick shots like that like flu vaccine
# Original Word: Inconvenient times 	 Lemmatized word:Inconvenient times
# Original Word: cant imagine 	 Lemmatized word:cant imagine
# Original Word: inability choose scheduling appointment 	 Lemmatized word:inability choose scheduling appointment
# Original Word: location campus car reach site 	 Lemmatized word:location campus car reach site
# Original Word: location campus car reach site 	 Lemmatized word:location campus car reach site
# Original Word: location campus car reach site 	 Lemmatized word:location campus car reach site
# Original Word:  	 Lemmatized word:
# Original Word: lot people getting 	 Lemmatized word:lot people getting
# Original Word: offcampus vaccine stand line vaccine no appointments like COVID testing 	 Lemmatized word:offcampus vaccine stand line vaccine no appointments like COVID testing
# Original Word: assigned random time 	 Lemmatized word:assigned random time
# Original Word: assigned random time 	 Lemmatized word:assigned random time
# Original Word: Work class 	 Lemmatized word:Work class
# Original Word: Nothing it 	 Lemmatized word:Nothing it
# Original Word: far away 	 Lemmatized word:far away
# Original Word: far away 	 Lemmatized word:far away
# Original Word: trusting especially company making harmful products cause cancer 	 Lemmatized word:trusting especially company making harmful products cause cancer
# Original Word: Lack time school work 	 Lemmatized word:Lack time school work
# Original Word: busy schedule worried effects 	 Lemmatized word:busy schedule worried effects
# Original Word: scheduled vaccine 	 Lemmatized word:scheduled vaccine
# Original Word: School 	 Lemmatized word:School
# Original Word: School 	 Lemmatized word:School
# Original Word: Phase  nonessential preexisting conditionsmorbidities person eligible vaccine based phased rollout 	 Lemmatized word:Phase  nonessential preexisting conditionsmorbidities person eligible vaccine based phased rollout
# Original Word: Lack supply 	 Lemmatized word:Lack supply
# Original Word: Lack supply 	 Lemmatized word:Lack supply
# Original Word: Availability 	 Lemmatized word:Availability
# Original Word: Availability 	 Lemmatized word:Availability
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word: stay Boone second dose 	 Lemmatized word:stay Boone second dose
# Original Word: stay Boone second dose 	 Lemmatized word:stay Boone second dose
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word: leaving work 	 Lemmatized word:leaving work
# Original Word: leaving work 	 Lemmatized word:leaving work
# Original Word: campus 	 Lemmatized word:campus
# Original Word: availability 	 Lemmatized word:availability
# Original Word: Im getting cant force too 	 Lemmatized word:Im getting cant force too
# Original Word: Im getting cant force too 	 Lemmatized word:Im getting cant force too
# Original Word: Im getting cant force too 	 Lemmatized word:Im getting cant force too
# Original Word: date time available vaccination 	 Lemmatized word:date time available vaccination
# Original Word: date time available vaccination 	 Lemmatized word:date time available vaccination
# Original Word: knowing effect body 	 Lemmatized word:knowing effect body
# Original Word: knowing effect body 	 Lemmatized word:knowing effect body
# Original Word: knowing effect body 	 Lemmatized word:knowing effect body
# Original Word: Transportation 	 Lemmatized word:Transportation
# Original Word: Transportation 	 Lemmatized word:Transportation
# Original Word: Transportation 	 Lemmatized word:Transportation
# Original Word: religious beliefs 	 Lemmatized word:religious beliefs
# Original Word: Classes 	 Lemmatized word:Classes
# Original Word: hearing available long lines hard time appointment etc 	 Lemmatized word:hearing available long lines hard time appointment etc
# Original Word: risks effects 	 Lemmatized word:risks effects
# Original Word: allergic itpeople medical issues needed moretime work 	 Lemmatized word:allergic itpeople medical issues needed moretime work
# Original Word: allergic itpeople medical issues needed moretime work 	 Lemmatized word:allergic itpeople medical issues needed moretime work
# Original Word: allergic itpeople medical issues needed moretime work 	 Lemmatized word:allergic itpeople medical issues needed moretime work
# Original Word: allergic itpeople medical issues needed moretime work 	 Lemmatized word:allergic itpeople medical issues needed moretime work
# Original Word: allergic itpeople medical issues needed moretime work 	 Lemmatized word:allergic itpeople medical issues needed moretime work
# Original Word: allergic itpeople medical issues needed moretime work 	 Lemmatized word:allergic itpeople medical issues needed moretime work
# Original Word: sure 	 Lemmatized word:sure
# Original Word: sure 	 Lemmatized word:sure
# Original Word: sure 	 Lemmatized word:sure
# Original Word: Distance 	 Lemmatized word:Distance
# Original Word
# Original Word: Making sign difficult 	 Lemmatized word:Making sign difficult
# Original Word: Making sign difficult 	 Lemmatized word:Making sign difficult
# Original Word: Making sign difficult 	 Lemmatized word:Making sign difficult
# Original Word: Long waits time slots interfere classes 	 Lemmatized word:Long waits time slots interfere classes
# Original Word: Long waits time slots interfere classes 	 Lemmatized word:Long waits time slots interfere classes
# Original Word: goes core belief enforce terrifying thought organization bodies unknown risk futurereactions especially built immunity contracting virus makes worried difficult 	 Lemmatized word:goes core belief enforce terrifying thought organization bodies unknown risk futurereactions especially built immunity contracting virus makes worried difficult
# Original Word: goes core belief enforce terrifying thought organization bodies unknown risk futurereactions especially built immunity contracting virus makes worried difficult 	 Lemmatized word:goes core belief enforce terrifying thought organization bodies unknown risk futurereactions especially built immunity contracting virus makes worried difficult
# Original Word: goes core belief enforce terrifying thought organization bodies unknown risk futurereactions especially built immunity contracting virus makes worried difficult 	 Lemmatized word:goes core belief enforce terrifying thought organization bodies unknown risk futurereactions especially built immunity contracting virus makes worried difficult
# Original Word: goes core belief enforce terrifying thought organization bodies unknown risk futurereactions especially built immunity contracting virus makes worried difficult 	 Lemmatized word:goes core belief enforce terrifying thought organization bodies unknown risk futurereactions especially built immunity contracting virus makes worried difficult
# Original Word: couldnt work 	 Lemmatized word:couldnt work
# Original Word: Im sure 	 Lemmatized word:Im sure
# Original Word: Im sure 	 Lemmatized word:Im sure
# Original Word: long distance 	 Lemmatized word:long distance
# Original Word: long distance 	 Lemmatized word:long distance
# Original Word: long distance 	 Lemmatized word:long distance
# Original Word: long distance 	 Lemmatized word:long distance
# Original Word: long distance 	 Lemmatized word:long distance
# Original Word: giving far live like blowing rock 	 Lemmatized word:giving far live like blowing rock
# Original Word: finding appointment fits schedule 	 Lemmatized word:finding appointment fits schedule
# Original Word: finding appointment fits schedule 	 Lemmatized word:finding appointment fits schedule
# Original Word: Health risks 	 Lemmatized word:Health risks
# Original Word: wait line Appointment 	 Lemmatized word:wait line Appointment
# Original Word: Hospital visit 	 Lemmatized word:Hospital visit
# Original Word: depending day time available 	 Lemmatized word:depending day time available
# Original Word: knowing effects 	 Lemmatized word:knowing effects
# Original Word: knowing effects 	 Lemmatized word:knowing effects
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word: needlephobia able 	 Lemmatized word:needlephobia able
# Original Word: teacher dying app state aborted fetal cells vaccine 	 Lemmatized word:teacher dying app state aborted fetal cells vaccine
# Original Word: teacher dying app state aborted fetal cells vaccine 	 Lemmatized word:teacher dying app state aborted fetal cells vaccine
# Original Word: Transportation 	 Lemmatized word:Transportation
# Original Word: Transportation 	 Lemmatized word:Transportation
# Original Word: confusing appointment making process 	 Lemmatized word:confusing appointment making process
# Original Word: time schedules difficult fit classes 	 Lemmatized word:time schedules difficult fit classes
# Original Word: time schedules difficult fit classes 	 Lemmatized word:time schedules difficult fit classes
# Original Word: Inconvenient location able choose timedate 	 Lemmatized word:Inconvenient location able choose timedate
# Original Word: vaccination sites far away 	 Lemmatized word:vaccination sites far away
# Original Word: Long LinesWaiting Periods 	 Lemmatized word:Long LinesWaiting Periods
# Original Word: Long LinesWaiting Periods 	 Lemmatized word:Long LinesWaiting Periods
# Original Word: Long LinesWaiting Periods 	 Lemmatized word:Long LinesWaiting Periods
# Original Word: want it 	 Lemmatized word:want it
# Original Word: want it 	 Lemmatized word:want it
# Original Word: want it 	 Lemmatized word:want it
# Original Word: want it 	 Lemmatized word:want it
# Original Word: want it 	 Lemmatized word:want it
# Original Word: want it 	 Lemmatized word:want it
# Original Word: want it 	 Lemmatized word:want it
# Original Word: want it 	 Lemmatized word:want it
# Original Word: want it 	 Lemmatized word:want it
# Original Word: want it 	 Lemmatized word:want it
# Original Word: want it 	 Lemmatized word:want it
# Original Word: want it 	 Lemmatized word:want it
# Original Word: thought negative effects health 	 Lemmatized word:thought negative effects health
# Original Word: thought negative effects health 	 Lemmatized word:thought negative effects health
# Original Word: advertising 	 Lemmatized word:advertise
# Original Word: advertising 	 Lemmatized word:advertise
# Original Word: advertising 	 Lemmatized word:advertise
# Original Word: advertising 	 Lemmatized word:advertise
# Original Word: advertising 	 Lemmatized word:advertise
# Original Word: advertising 	 Lemmatized word:advertise
# Original Word: advertising 	 Lemmatized word:advertise
# Original Word: advertising 	 Lemmatized word:advertise
# Original Word: advertising 	 Lemmatized word:advertise
# Original Word: advertising 	 Lemmatized word:advertise
# Original Word: advertising 	 Lemmatized word:advertise
# Original Word: advertising 	 Lemmatized word:advertise
# Original Word: lack transportationconflicting schedule primary worries 	 Lemmatized word:lack transportationconflicting schedule primary worries
# Original Word: lack transportationconflicting schedule primary worries 	 Lemmatized word:lack transportationconflicting schedule primary worries
# Original Word: lack transportationconflicting schedule primary worries 	 Lemmatized word:lack transportationconflicting schedule primary worries
# Original Word: lack transportationconflicting schedule primary worries 	 Lemmatized word:lack transportationconflicting schedule primary worries
# Original Word: lack transportationconflicting schedule primary worries 	 Lemmatized word:lack transportationconflicting schedule primary worries
# Original Word: lack transportationconflicting schedule primary worries 	 Lemmatized word:lack transportationconflicting schedule primary worries
# Original Word: lack transportationconflicting schedule primary worries 	 Lemmatized word:lack transportationconflicting schedule primary worries
# Original Word: lack transportationconflicting schedule primary worries 	 Lemmatized word:lack transportationconflicting schedule primary worries
# Original Word: email saying group able vaccine its group eligible 	 Lemmatized word:email saying group able vaccine its group eligible
# Original Word: dont completely understand aspects Im sure safe 	 Lemmatized word:dont completely understand aspects Im sure safe
# Original Word: dont completely understand aspects Im sure safe 	 Lemmatized word:dont completely understand aspects Im sure safe
# Original Word: dont completely understand aspects Im sure safe 	 Lemmatized word:dont completely understand aspects Im sure safe
# Original Word: Johnson  Johnson vaccine 	 Lemmatized word:Johnson  Johnson vaccine
# Original Word: Johnson  Johnson vaccine 	 Lemmatized word:Johnson  Johnson vaccine
# Original Word: Johnson  Johnson vaccine 	 Lemmatized word:Johnson  Johnson vaccine
# Original Word: Johnson  Johnson vaccine 	 Lemmatized word:Johnson  Johnson vaccine
# Original Word: new 	 Lemmatized word:new
# Original Word: new 	 Lemmatized word:new
# Original Word: told cant tomorrow 	 Lemmatized word:told cant tomorrow
# Original Word: Lack knowing effects 	 Lemmatized word:Lack knowing effects
# Original Word: Lack knowing effects 	 Lemmatized word:Lack knowing effects
# Original Word: Boone 	 Lemmatized word:Boone
# Original Word: effects pertain vaccine 	 Lemmatized word:effects pertain vaccine
# Original Word: effects pertain vaccine 	 Lemmatized word:effects pertain vaccine
# Original Word: effects pertain vaccine 	 Lemmatized word:effects pertain vaccine
# Original Word: effects pertain vaccine 	 Lemmatized word:effects pertain vaccine
# Original Word: effects pertain vaccine 	 Lemmatized word:effects pertain vaccine
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word:  	 Lemmatized word:
# Original Word: times April difficult me 	 Lemmatized word:times April difficult me
# Original Word: allergic tree nuts time person watch incase reaction 	 Lemmatized word:allergic tree nuts time person watch incase reaction
# Original Word: Complications current schedule 	 Lemmatized word:Complications current schedule
# Original Word: Complications current schedule 	 Lemmatized word:Complications current schedule
# Original Word: Complications current schedule 	 Lemmatized word:Complications current schedule
# Original Word: vaccines offered oncampus 	 Lemmatized word:vaccines offered oncampus
# Original Word: vaccines offered oncampus 	 Lemmatized word:vaccines offered oncampus
# Original Word: vaccines offered oncampus 	 Lemmatized word:vaccines offered oncampus
# Original Word: vaccines offered oncampus 	 Lemmatized word:vaccines offered oncampus
# Original Word: vaccines offered oncampus 	 Lemmatized word:vaccines offered oncampus
# Original Word: vaccines offered oncampus 	 Lemmatized word:vaccines offered oncampus

# %% [markdown]
# # Word Cloud

# %%
#!pip install wordcloud

# %%
# lets plot the Wordscloud


# for Wordscloud
from wordcloud import WordCloud, STOPWORDS
stopwords = set(STOPWORDS)

# %%
wordcloud =WordCloud(stopwords = stopwords , width=2000 , height=1600, background_color="black").generate(''.join(dataset['Reasons for Hesitation']))
plt.figure(figsize=(20,10))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
plt.tight_layout (pad=0)
plt.title("Vocabulary from Reasons for Hesitation", fontsize = 20)
plt.show()

# %%
wordcloud =WordCloud(stopwords = stopwords , width=2000 , height=1600, background_color="black").generate(''.join(dataset['Obstacles']))
plt.figure(figsize=(20,10))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
plt.tight_layout (pad=0)
plt.title("Vocabulary from Obstacles", fontsize = 20)
plt.show()

# %%
wordcloud =WordCloud(stopwords = stopwords , width=2000 , height=1600, background_color="black").generate(''.join(dataset['Accessibility ']))
plt.figure(figsize=(20,10))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
plt.tight_layout (pad=0)
plt.title("Vocabulary from Accessibility", fontsize = 20)
plt.show()

# %% [markdown]
# # Commonest Words

# %%
from collections import Counter


# In[ ]:


def comm(d,n=30):
    doc = Counter(d)
    common = doc.most_common(n)

    return common


# In[ ]:


comm(dataset['Reasons for Hesitation'])
# Out:
# [('effects', 45),
#  ('effects vaccine', 30),
#  ('Nothing Thats thing years Ill', 24),
#  ('Heard kill', 24),
#  ('Different effacies effects general malaise', 20),
#  ('People dying', 18),
#  ('Bad allergic reaction', 18),
#  ('Different things health long run', 17),
#  ('Possibility affect reproductive system', 17),
#  ('affects', 16),
#  ('General disruption everyday life days Johnson  Johnson', 16),
#  ('Infertility', 15),
#  ('Media portrayals possible future problems vaccine and similar arguments',
#   14),
#  ('Infertility issues', 14),
#  ('sideeffects efficacy vaccine', 13),
#  ('Severe effects', 13),
#  ('Fear effects fear test subjects', 12),
#  ('Fertility Issues', 12),
#  ('testing long term effects', 12),
#  ('News article individual died vaccine', 12),
#  ('infertility', 11),
#  ('people mentioned strong reaction got received vaccine', 11),
#  ('People getting fevers cold chills coughing day understand purpose making sick vax order sick virus',
#   10),
#  ('Weird symptoms', 10),
#  ('heard short term effect Im scared vaccine came fast dont know long term',
#   10),
#  ('effects fertility', 10),
#  ('Blatant misinformation online purposeful scare tactics news sources misleading titles etc',
#   10),
#  ('Targeted advertisement minority groups suspicious', 10),
#  ('Feeling sick muscle sorescramps fever', 9),
#  ('brand vaccine completed use tissues aborted fetuses vaccines effects getting vaccine similar worse actual symptoms COVID experience certain type vaccine targets mRNA unorthodox vaccination method lead infertility especially women',
#   9)]

# %%
comm(dataset['Obstacles'])
# Out:
# [('', 137),
#  ('VAERS cdc website mRNA vaccines leading ADE past finally clinical trial vaccine  people actually received vaccine trial',
#   88),
#  ('Transportation', 22),
#  ('knowing long term effects', 15),
#  ('School', 15),
#  ('money wise people want', 14),
#  ('communication available', 13),
#  ('think would', 12),
#  ('want it', 12),
#  ('advertising', 12),
#  ('Scheduling', 11),
#  ('Location', 11),
#  ('Strict times high list access vaccine', 11),
#  ('sure', 10),
#  ('Proof effects internal organs', 10),
#  ('Distance', 9),
#  ('wont vaccine', 9),
#  ('campus', 8),
#  ('Time', 8),
#  ('Location central vaccination times cater individual schedules', 8),
#  ('lack transportationconflicting schedule primary worries', 8),
#  ('Nothing', 7),
#  ('far away', 7),
#  ('Availability', 7),
#  ('school work job', 7),
#  ('way transportation', 7),
#  ('minute emergencies', 7),
#  ('personal time possible affects', 7),
#  ('Farther home', 6),
#  ('allergic itpeople medical issues needed moretime work', 6)]

# %%
comm(dataset['Accessibility '])
# Out:
# [('actual clinical trial rushed', 88),
#  ('', 70),
#  ('campus', 16),
#  ('Im sure', 16),
#  ('Location', 14),
#  ('noting', 14),
#  ('Learning information effects people', 13),
#  ('notification when how', 13),
#  ('Available test sites', 13),
#  ('advertising', 12),
#  ('Easy access', 11),
#  ('Variable flexible times safe conditions', 11),
#  ('research', 10),
#  ('provden affects internal organs time', 10),
#  ('sure', 9),
#  ('information', 9),
#  ('know', 9),
#  ('flexible schedule', 9),
#  ('free', 8),
#  ('vaccination site campus possibly drivethrough', 8),
#  ('multiple flexible datestimes available appointments', 8),
#  ('near', 8),
#  ('open schedule ease transportation', 8),
#  ('Transportation', 7),
#  ('Availability', 7),
#  ('Unsure', 7),
#  ('dont know', 7),
#  ('Scheduling', 7),
#  ('benefits assurances big names school receiving', 7),
#  ('vaccinated outcomes', 7)]

# %% [markdown]
# # Categorizing the commonest words

# %%
Cat_dataset = pd.read_excel("Categories.xlsx")

# %%
Cat_dataset
# Out:
#                                             OBSTACLES OBSTACLES CATEGORIES  \
# 0    ('VAERS website mRNA vaccines leading past fi...             Concerns
# 1                             ('Transportation', 22),        Accessibility
# 2                  ('knowing long term effects', 15),         Organisation
# 3                                     ('School', 15),                  Pro
# 4                     ('money wise people want', 14),             Concerns
# 5                    ('communication available', 13),        Communication
# 6                                       ('sure', 12),                  Pro
# 7                                       ('away', 12),                  Pro
# 8                                ('think would', 12),        Communication
# 9                                       ('want', 12),         Organisation
# 10                               ('advertising', 12),        Accessibility
# 11                                ('Scheduling', 11),                  Pro
# 12                                   ('Nothing', 11),        Accessibility
# 13                                  ('Location', 11),             Concerns
# 14     ('Strict times high list access vaccine', 11),                 Anti
# 15             ('Proof effects internal organs', 10),        Accessibility
# 16                                   ('Distance', 9),        Accessibility
# 17                               ('wont vaccine', 9),         Organisation
# 18                                     ('campus', 8),        Accessibility
# 19                                       ('Time', 8),        Accessibility
# 20                                   ('location', 8),         Organisation
# 21                             ('transportation', 8),        Accessibility
# 22   ('Location central vaccination times cater in...         Organisation
# 23   ('lack transportation conflicting schedule pr...             Concerns
# 24                                    ('vaccine', 7),        Accessibility
# 25                               ('Availability', 7),        Accessibility
# 26                                ('school work', 7),             Concerns
# 27                         ('minute emergencies', 7),           Incentives
# 28             ('personal time possible affects', 7)]        Accessibility
# 29                                                NaN                  NaN
#
#                                             HESITANCY HESITANCY CATGORIES  \
# 0                                   [('effects', 52),        Side effects
# 1                            ('effects vaccine', 30),        Side effects
# 2                   ('Nothing That thing years', 24),       Effectiveness
# 3                                 ('Heard kill', 24),               Death
# 4    ('Different effacies effects general malaise'...       Effectiveness
# 5                               ('People dying', 18),               Death
# 6                          ('allergic reaction', 18),        Side effects
# 7               ('Different things health long', 17),        Side effects
# 8     ('Possibility affect reproductive system', 17),           Fertility
# 9                                    ('affects', 16),        Side effects
# 10   ('General disruption everyday life days Johns...        Organisation
# 11                               ('Infertility', 15),           Fertility
# 12   ('Media portrayals possible future problems v...       Communication
# 13                        ('Infertility issues', 14),           Fertility
# 14             ('side effects efficacy vaccine', 13),        Side effects
# 15                            ('Severe effects', 13),        Side effects
# 16           ('Fear effects fear test subjects', 12),        Side effects
# 17                          ('Fertility Issues', 12),           Fertility
# 18                 ('testing long term effects', 12),        Side effects
# 19      ('News article individual died vaccine', 12),       Communication
# 20                               ('infertility', 11),           Fertility
# 21   ('people mentioned strong reaction received v...        Side effects
# 22  ) ('People getting fevers cold chills coughing...        Side effects
# 23                            ('Weird symptoms', 10),        Side effects
# 24   ('heard short term effect scared vaccine came...        Side effects
# 25                         ('effects fertility', 10),           Fertility
# 26   ('Blatant misinformation online purposeful sc...       Communication
# 27   ('Targeted advertisement minority groups susp...       Communication
# 28     ('Feeling sick muscle sores cramps fever', 9),        Side effects
# 29   ('brand vaccine completed tissues aborted fet...        Side effects
#
#                                          ACCESSIBILTY ACCESSIBILITY CATEGORIES
# 0               ('actual clinical trial rushed', 88),                 Concerns
# 1                                       ('sure', 25),                      Pro
# 2                                     ('campus', 17),            Accessibility
# 3                                   ('Location', 14),            Accessibility
# 4                                     ('noting', 14),                     Anti
# 5        ('Learning information effects people', 13),            Communication
# 6                          ('notification when', 13),            Communication
# 7                       ('Available test sites', 13),            Accessibility
# 8                                ('advertising', 12),            Communication
# 9                                ('Easy access', 11),            Accessibility
# 10   ('Variable flexible times safe conditions', 11),             Organisation
# 11                                  ('research', 10),                 Concerns
# 12                           ('getting vaccine', 10),                      Pro
# 13      ('provden affects internal organs time', 10),                 Concerns
# 14                                ('information', 9),            Communication
# 15                                       ('know', 9),                 Concerns
# 16                          ('flexible schedule', 9),             Organisation
# 17                                       ('free', 8),               Incentives
# 18   ('vaccination site campus possibly drive thro...            Accessibility
# 19   ('multiple flexible dates times available app...            Accessibility
# 20                                       ('near', 8),            Accessibility
# 21          ('open schedule ease transportation', 8),            Accessibility
# 22                             ('Transportation', 7),            Accessibility
# 23                               ('Availability', 7),            Accessibility
# 24                                     ('Unsure', 7),                 Concerns
# 25                                   ('don know', 7),                 Concerns
# 26                                 ('Scheduling', 7),             Organisation
# 27   ('benefits assurances names school receiving'...               Incentives
# 28                        ('vaccinated outcomes', 7)]            Communication
# 29                                                NaN                      NaN

# %%
plt.title("OBSTACLES CATEGORIES ")
sns.countplot(Cat_dataset['OBSTACLES CATEGORIES'])
plt.show()
# Out:
# C:\Users\Owner\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
plt.title("HESITANCY CATGORIES")
sns.countplot(Cat_dataset['HESITANCY CATGORIES'])
plt.show()
# Out:
# C:\Users\Owner\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
plt.title("ACCESSIBILITY CATEGORIES")
sns.countplot(Cat_dataset['ACCESSIBILITY CATEGORIES'])
plt.show()
# Out:
# C:\Users\Owner\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# # Sentiment Analysis
#     Polarity and Subjectivity

# %%
from textblob import TextBlob
def sentiment_analysis(text):
    blob = TextBlob(text)
    pol = blob.sentiment.polarity
    subj = blob.sentiment.subjectivity
    if pol < 0:
        result = "negative"
    elif pol == 0:
        result = "neutral"
    else:
        result = "positive"
    return result
    #return  {"pol": {pol}, "subj": subj, "label": result}

# %%
def pol(text):
    blob = TextBlob(text)
    pol = blob.sentiment.polarity
    return pol

# %%
def subj(text):
    blob = TextBlob(text)
    subj = blob.sentiment.subjectivity
    return subj

# %%
dataset["Reasons for Hesitation_pol"] =dataset["Reasons for Hesitation"].apply(pol)
dataset["Reasons for Hesitation_subj"] =dataset["Reasons for Hesitation"].apply(subj)

# %%
dataset["Reasons for Hesitation_pol"]
# Out:
# 0      -0.025000
# 1      -0.025000
# 2      -0.025000
# 3      -0.025000
# 4      -0.025000
#           ...
# 1680   -0.083333
# 1681   -0.083333
# 1682    0.000000
# 1683    0.000000
# 1684    0.000000
# Name: Reasons for Hesitation_pol, Length: 1685, dtype: float64

# %%
dataset["Reasons for Hesitation_sent"] =dataset["Reasons for Hesitation"].apply(sentiment_analysis)
dataset["Obstacles_sent"] = dataset["Obstacles"].apply(sentiment_analysis)
dataset["Accessibility_sent"] = dataset["Accessibility "].apply(sentiment_analysis)

# %%
dataset["Reasons for Hesitation_sent"]
# Out:
# 0       negative
# 1       negative
# 2       negative
# 3       negative
# 4       negative
#           ...
# 1680    negative
# 1681    negative
# 1682     neutral
# 1683     neutral
# 1684     neutral
# Name: Reasons for Hesitation_sent, Length: 1685, dtype: object

# %%
dataset
# Out:
#      Respondent Age  Gender  COVID-19 Jab?   Race  Any reason for Hesitation  \
# 0         Staff  19       2              1  White                        1.0
# 1       Student  20       2              0  White                        2.0
# 2       Student  19       1              0  White                        2.0
# 3       Student  44       1              0  White                        2.0
# 4         Staff  30       1              1  White                        2.0
# ...         ...  ..     ...            ...    ...                        ...
# 1680    Student  20       1              0  White                        1.0
# 1681    Student  28       1              1  White                        1.0
# 1682      Staff  28       1              1  White                        1.0
# 1683    Student  19       1              0  White                        2.0
# 1684    Student  19       1              0  White                        2.0
#
#                                 Reasons for Hesitation  Hesistation Status  \
# 0                     Different things health long run                 NaN
# 1                     Different things health long run                 3.0
# 2                     Different things health long run                 3.0
# 3                     Different things health long run                 3.0
# 4                     Different things health long run                 0.0
# ...                                                ...                 ...
# 1680  relative newness vaccine given slight hesitation                 3.0
# 1681  relative newness vaccine given slight hesitation                 0.0
# 1682                      Heard faces gotten paralyzed                 0.0
# 1683                      Heard faces gotten paralyzed                 3.0
# 1684                      Heard faces gotten paralyzed                 3.0
#
#               Trust Level     Safety Level  ...  \
# 0            Mostly trust      Mostly safe  ...
# 1            Mostly trust        Very safe  ...
# 2            Mostly trust        Very safe  ...
# 3            Mostly trust        Very safe  ...
# 4            Mostly trust        Very safe  ...
# ...                   ...              ...  ...
# 1680         Mostly trust      Mostly safe  ...
# 1681         Mostly trust      Mostly safe  ...
# 1682  Do not trust at all  Not safe at all  ...
# 1683         Mostly trust      Mostly safe  ...
# 1684         Mostly trust      Mostly safe  ...
#
#                                      Accessibility   \
# 0                               Making appointments
# 1                               Making appointments
# 2                        allowed exempt classes day
# 3                        allowed exempt classes day
# 4                        allowed exempt classes day
# ...                                             ...
# 1680  Mail delivery vaccines way distribute locally
# 1681  Mail delivery vaccines way distribute locally
# 1682  Mail delivery vaccines way distribute locally
# 1683  Mail delivery vaccines way distribute locally
# 1684  Mail delivery vaccines way distribute locally
#
#                                        Obstacles  \
# 0                          hour half away campus
# 1     inability transportation vaccination sites
# 2                                     Scheduling
# 3                                     Scheduling
# 4                                     Scheduling
# ...                                          ...
# 1680                   vaccines offered oncampus
# 1681                   vaccines offered oncampus
# 1682                   vaccines offered oncampus
# 1683                   vaccines offered oncampus
# 1684                   vaccines offered oncampus
#
#                                          Obstacles_tk  \
# 0                          [hour, half, away, campus]
# 1     [inability, transportation, vaccination, sites]
# 2                                        [Scheduling]
# 3                                        [Scheduling]
# 4                                        [Scheduling]
# ...                                               ...
# 1680                    [vaccines, offered, oncampus]
# 1681                    [vaccines, offered, oncampus]
# 1682                    [vaccines, offered, oncampus]
# 1683                    [vaccines, offered, oncampus]
# 1684                    [vaccines, offered, oncampus]
#
#                               Reasons for Hesitation_tk  \
# 0                [Different, things, health, long, run]
# 1                [Different, things, health, long, run]
# 2                [Different, things, health, long, run]
# 3                [Different, things, health, long, run]
# 4                [Different, things, health, long, run]
# ...                                                 ...
# 1680  [relative, newness, vaccine, given, slight, he...
# 1681  [relative, newness, vaccine, given, slight, he...
# 1682                  [Heard, faces, gotten, paralyzed]
# 1683                  [Heard, faces, gotten, paralyzed]
# 1684                  [Heard, faces, gotten, paralyzed]
#
#                                       Accessibility_tk   \
# 0                                [Making, appointments]
# 1                                [Making, appointments]
# 2                       [allowed, exempt, classes, day]
# 3                       [allowed, exempt, classes, day]
# 4                       [allowed, exempt, classes, day]
# ...                                                 ...
# 1680  [Mail, delivery, vaccines, way, distribute, lo...
# 1681  [Mail, delivery, vaccines, way, distribute, lo...
# 1682  [Mail, delivery, vaccines, way, distribute, lo...
# 1683  [Mail, delivery, vaccines, way, distribute, lo...
# 1684  [Mail, delivery, vaccines, way, distribute, lo...
#
#      Reasons for Hesitation_pol  Reasons for Hesitation_subj  \
# 0                     -0.025000                     0.500000
# 1                     -0.025000                     0.500000
# 2                     -0.025000                     0.500000
# 3                     -0.025000                     0.500000
# 4                     -0.025000                     0.500000
# ...                         ...                          ...
# 1680                  -0.083333                     0.083333
# 1681                  -0.083333                     0.083333
# 1682                   0.000000                     0.000000
# 1683                   0.000000                     0.000000
# 1684                   0.000000                     0.000000
#
#       Reasons for Hesitation_sent Obstacles_sent Accessibility_sent
# 0                        negative       negative            neutral
# 1                        negative        neutral            neutral
# 2                        negative        neutral            neutral
# 3                        negative        neutral            neutral
# 4                        negative        neutral            neutral
# ...                           ...            ...                ...
# 1680                     negative        neutral            neutral
# 1681                     negative        neutral            neutral
# 1682                      neutral        neutral            neutral
# 1683                      neutral        neutral            neutral
# 1684                      neutral        neutral            neutral
#
# [1685 rows x 21 columns]

# %%
dataset["Reasons for Hesitation_sent"].value_counts()
# Out:
# neutral     807
# negative    543
# positive    335
# Name: Reasons for Hesitation_sent, dtype: int64

# %%
dataset["Obstacles_sent"].value_counts()
# Out:
# neutral     1023
# negative     352
# positive     310
# Name: Obstacles_sent, dtype: int64

# %%
dataset["Accessibility_sent"].value_counts()
# Out:
# neutral     1136
# positive     465
# negative      84
# Name: Accessibility_sent, dtype: int64

# %%
sns.countplot(dataset["Reasons for Hesitation_sent"])
# Out:
# C:\Users\Owner\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='Reasons for Hesitation_sent', ylabel='count'>

# %%
sns.countplot(dataset["Obstacles_sent"])
# Out:
# C:\Users\Owner\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='Obstacles_sent', ylabel='count'>

# %%
sns.countplot(dataset["Accessibility_sent"])
# Out:
# C:\Users\Owner\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='Accessibility_sent', ylabel='count'>

# %% [markdown]
# # Converting to numbers

# %%
#converting to numbers
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()

dataset["Accessibility_n"] = lb.fit_transform(dataset["Accessibility "])
dataset["Obstacles_n"] = lb.fit_transform(dataset["Obstacles"])
dataset["Reasons for Hesitation_n"] = lb.fit_transform(dataset["Reasons for Hesitation"])
dataset["Respondent_n"] = lb.fit_transform(dataset["Respondent"])
dataset["Race_n"] = lb.fit_transform(dataset["Race"])
dataset["Confidence Level_n"] = lb.fit_transform(dataset["Confidence Level"])
dataset["Trust Level_n"] = lb.fit_transform(dataset["Trust Level"])
dataset["Safety Level_n"] = lb.fit_transform(dataset["Safety Level"])

# %% [markdown]
# Clustering

# %%
#clustering

from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
X = dataset[['Reasons for Hesitation_n', 'Obstacles_n']]
kmeansmodel = KMeans(n_clusters= 5, init='k-means++', random_state=0)
dataset['Cluster'] = kmeansmodel.fit_predict(X)

# %%
dataset['Cluster']
# Out:
# 0       3
# 1       3
# 2       2
# 3       2
# 4       2
#        ..
# 1680    0
# 1681    0
# 1682    3
# 1683    3
# 1684    3
# Name: Cluster, Length: 1685, dtype: int32

# %%
dataset
# Out:
#      Respondent Age  Gender  COVID-19 Jab?   Race  Any reason for Hesitation  \
# 0         Staff  19       2              1  White                        1.0
# 1       Student  20       2              0  White                        2.0
# 2       Student  19       1              0  White                        2.0
# 3       Student  44       1              0  White                        2.0
# 4         Staff  30       1              1  White                        2.0
# ...         ...  ..     ...            ...    ...                        ...
# 1680    Student  20       1              0  White                        1.0
# 1681    Student  28       1              1  White                        1.0
# 1682      Staff  28       1              1  White                        1.0
# 1683    Student  19       1              0  White                        2.0
# 1684    Student  19       1              0  White                        2.0
#
#                                 Reasons for Hesitation  Hesistation Status  \
# 0                     Different things health long run                 NaN
# 1                     Different things health long run                 3.0
# 2                     Different things health long run                 3.0
# 3                     Different things health long run                 3.0
# 4                     Different things health long run                 0.0
# ...                                                ...                 ...
# 1680  relative newness vaccine given slight hesitation                 3.0
# 1681  relative newness vaccine given slight hesitation                 0.0
# 1682                      Heard faces gotten paralyzed                 0.0
# 1683                      Heard faces gotten paralyzed                 3.0
# 1684                      Heard faces gotten paralyzed                 3.0
#
#               Trust Level     Safety Level  ... Accessibility_sent  \
# 0            Mostly trust      Mostly safe  ...            neutral
# 1            Mostly trust        Very safe  ...            neutral
# 2            Mostly trust        Very safe  ...            neutral
# 3            Mostly trust        Very safe  ...            neutral
# 4            Mostly trust        Very safe  ...            neutral
# ...                   ...              ...  ...                ...
# 1680         Mostly trust      Mostly safe  ...            neutral
# 1681         Mostly trust      Mostly safe  ...            neutral
# 1682  Do not trust at all  Not safe at all  ...            neutral
# 1683         Mostly trust      Mostly safe  ...            neutral
# 1684         Mostly trust      Mostly safe  ...            neutral
#
#      Accessibility_n Obstacles_n Reasons for Hesitation_n Respondent_n Race_n  \
# 0                201         417                       39            0     18
# 1                201         425                       39            1     18
# 2                335         211                       39            1     18
# 3                335         211                       39            1     18
# 4                335         211                       39            0     18
# ...              ...         ...                      ...          ...    ...
# 1680             200         652                      322            1     18
# 1681             200         652                      322            1     18
# 1682             200         652                       62            0     18
# 1683             200         652                       62            1     18
# 1684             200         652                       62            1     18
#
#       Confidence Level_n  Trust Level_n Safety Level_n Cluster
# 0                      3              2              0       3
# 1                      4              2              3       3
# 2                      4              2              3       2
# 3                      4              2              3       2
# 4                      4              2              3       2
# ...                  ...            ...            ...     ...
# 1680                   3              2              0       0
# 1681                   3              2              0       0
# 1682                   0              1              1       3
# 1683                   3              2              0       3
# 1684                   3              2              0       3
#
# [1685 rows x 30 columns]

# %% [markdown]
# Distribution Plot

# %%
plt.rcParams['figure.figsize'] = (10,4)
plt.subplot(1,2,1)
sns.distplot(dataset["Reasons for Hesitation_pol"])

plt.subplot(1,2,2)
sns.distplot(dataset["Reasons for Hesitation_subj"])
plt.show()
# Out:
# C:\Users\Owner\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# C:\Users\Owner\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %% [markdown]
# Scattered plot of Reason for Hesitation: It's polarity and subjectivity

# %%
plt.title("Relationship between Hesistation Polarity and Subjectivity")
sns.scatterplot(dataset["Reasons for Hesitation_subj"], dataset["Reasons for Hesitation_pol"])
plt.show()
# Out:
# C:\Users\Owner\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# ## Visualizing the Most Frequent Words

# %%
## Visualizing the Most Frequent Words

from sklearn.feature_extraction.text import CountVectorizer


cv = CountVectorizer(stop_words = 'english')
words = cv.fit_transform(dataset['Reasons for Hesitation'])
sum_words = words.sum(axis=0)


words_freq = [(word, sum_words[0, idx]) for word, idx in cv.vocabulary_.items()]
words_freq = sorted(words_freq, key = lambda x: x[1], reverse = True)
frequency = pd.DataFrame(words_freq, columns=['word', 'freq'])

plt.style.use('fivethirtyeight')
color = plt.cm.ocean(np.linspace(0, 1, 20))
frequency.head(10).plot(x='word', y='freq', kind='bar', figsize=(15, 6), color = color)
plt.title("Most Frequently Occuring Words - Top 10")
plt.show()

# %%
from sklearn.feature_extraction.text import CountVectorizer


cv = CountVectorizer(stop_words = 'english')
words = cv.fit_transform(dataset['Reasons for Hesitation'])
sum_words = words.sum(axis=0)


words_freq = [(word, sum_words[0, idx]) for word, idx in cv.vocabulary_.items()]
words_freq = sorted(words_freq, key = lambda x: x[1], reverse = True)
frequency = pd.DataFrame(words_freq, columns=['word', 'freq'])

plt.style.use('fivethirtyeight')
color = plt.cm.ocean(np.linspace(0, 1, 20))
frequency.tail(10).plot(x='word', y='freq', kind='bar', figsize=(15, 6), color = color)
plt.title("Least Frequently Occuring Words - Top 10")
plt.show()

# %%
dataset.shape
# Out:
# (1685, 30)

# %% [markdown]
# # Extracting the Features using the Tfidf Vectorizer

# %%
# Extracting the Features using the Tfidf Vectorizer for obstacles

from sklearn.feature_extraction.text import TfidfVectorizer

tf = TfidfVectorizer(max_features = 2500)
x = tf.fit_transform(obstacles).toarray()
y = dataset.iloc[:, 3].values

print(x.shape)
print(y.shape)
# Out:
# (3370, 1074)
# (1685,)

# %%
dataset
# Out:
#      Respondent Age  Gender  COVID-19 Jab?   Race  Any reason for Hesitation  \
# 0         Staff  19       2              1  White                        1.0
# 1       Student  20       2              0  White                        2.0
# 2       Student  19       1              0  White                        2.0
# 3       Student  44       1              0  White                        2.0
# 4         Staff  30       1              1  White                        2.0
# ...         ...  ..     ...            ...    ...                        ...
# 1680    Student  20       1              0  White                        1.0
# 1681    Student  28       1              1  White                        1.0
# 1682      Staff  28       1              1  White                        1.0
# 1683    Student  19       1              0  White                        2.0
# 1684    Student  19       1              0  White                        2.0
#
#                                 Reasons for Hesitation  Hesistation Status  \
# 0                     Different things health long run                 NaN
# 1                     Different things health long run                 3.0
# 2                     Different things health long run                 3.0
# 3                     Different things health long run                 3.0
# 4                     Different things health long run                 0.0
# ...                                                ...                 ...
# 1680  relative newness vaccine given slight hesitation                 3.0
# 1681  relative newness vaccine given slight hesitation                 0.0
# 1682                      Heard faces gotten paralyzed                 0.0
# 1683                      Heard faces gotten paralyzed                 3.0
# 1684                      Heard faces gotten paralyzed                 3.0
#
#               Trust Level     Safety Level  ... Accessibility_sent  \
# 0            Mostly trust      Mostly safe  ...            neutral
# 1            Mostly trust        Very safe  ...            neutral
# 2            Mostly trust        Very safe  ...            neutral
# 3            Mostly trust        Very safe  ...            neutral
# 4            Mostly trust        Very safe  ...            neutral
# ...                   ...              ...  ...                ...
# 1680         Mostly trust      Mostly safe  ...            neutral
# 1681         Mostly trust      Mostly safe  ...            neutral
# 1682  Do not trust at all  Not safe at all  ...            neutral
# 1683         Mostly trust      Mostly safe  ...            neutral
# 1684         Mostly trust      Mostly safe  ...            neutral
#
#      Accessibility_n Obstacles_n Reasons for Hesitation_n Respondent_n Race_n  \
# 0                201         417                       39            0     18
# 1                201         425                       39            1     18
# 2                335         211                       39            1     18
# 3                335         211                       39            1     18
# 4                335         211                       39            0     18
# ...              ...         ...                      ...          ...    ...
# 1680             200         652                      322            1     18
# 1681             200         652                      322            1     18
# 1682             200         652                       62            0     18
# 1683             200         652                       62            1     18
# 1684             200         652                       62            1     18
#
#       Confidence Level_n  Trust Level_n Safety Level_n Cluster
# 0                      3              2              0       3
# 1                      4              2              3       3
# 2                      4              2              3       2
# 3                      4              2              3       2
# 4                      4              2              3       2
# ...                  ...            ...            ...     ...
# 1680                   3              2              0       0
# 1681                   3              2              0       0
# 1682                   0              1              1       3
# 1683                   3              2              0       3
# 1684                   3              2              0       3
#
# [1685 rows x 30 columns]

# %%
def polarity(text):
    blob = TextBlob(text)
    pol = blob.sentiment.polarity
    if pol < 0:
        result = "negative"
    elif pol == 0:
        result = "neutral"
    else:
        result = "positive"
    return result

# %%
dataset['pol']  = dataset["Reasons for Hesitation"].apply(polarity)

# %%
dataset['pol']
# Out:
# 0       negative
# 1       negative
# 2       negative
# 3       negative
# 4       negative
#           ...
# 1680    negative
# 1681    negative
# 1682     neutral
# 1683     neutral
# 1684     neutral
# Name: pol, Length: 1685, dtype: object

# %%
#Negativity and Positivty of Polarity

df = dataset[dataset['pol'] != 'neutral']

# %%
df
# Out:
#      Respondent Age  Gender  COVID-19 Jab?   Race  Any reason for Hesitation  \
# 0         Staff  19       2              1  White                        1.0
# 1       Student  20       2              0  White                        2.0
# 2       Student  19       1              0  White                        2.0
# 3       Student  44       1              0  White                        2.0
# 4         Staff  30       1              1  White                        2.0
# ...         ...  ..     ...            ...    ...                        ...
# 1676    Student  20       1              0  White                        2.0
# 1677    Student  18       1              0  White                        3.0
# 1679    Student  18       1              0  White                        1.0
# 1680    Student  20       1              0  White                        1.0
# 1681    Student  28       1              1  White                        1.0
#
#                                 Reasons for Hesitation  Hesistation Status  \
# 0                     Different things health long run                 NaN
# 1                     Different things health long run                 3.0
# 2                     Different things health long run                 3.0
# 3                     Different things health long run                 3.0
# 4                     Different things health long run                 0.0
# ...                                                ...                 ...
# 1676                allergies afraid allergic reaction                 3.0
# 1677                allergies afraid allergic reaction                 3.0
# 1679  relative newness vaccine given slight hesitation                 3.0
# 1680  relative newness vaccine given slight hesitation                 3.0
# 1681  relative newness vaccine given slight hesitation                 0.0
#
#          Trust Level     Safety Level  ... Accessibility_n Obstacles_n  \
# 0       Mostly trust      Mostly safe  ...             201         417
# 1       Mostly trust        Very safe  ...             201         425
# 2       Mostly trust        Very safe  ...             335         211
# 3       Mostly trust        Very safe  ...             335         211
# 4       Mostly trust        Very safe  ...             335         211
# ...              ...              ...  ...             ...         ...
# 1676    Mostly trust      Mostly safe  ...             251          34
# 1677  Somewhat trust  Not safe at all  ...             251          34
# 1679    Mostly trust      Mostly safe  ...             200         652
# 1680    Mostly trust      Mostly safe  ...             200         652
# 1681    Mostly trust      Mostly safe  ...             200         652
#
#      Reasons for Hesitation_n Respondent_n Race_n Confidence Level_n  \
# 0                          39            0     18                  3
# 1                          39            1     18                  4
# 2                          39            1     18                  4
# 3                          39            1     18                  4
# 4                          39            0     18                  4
# ...                       ...          ...    ...                ...
# 1676                      180            1     18                  3
# 1677                      180            1     18                  2
# 1679                      322            1     18                  3
# 1680                      322            1     18                  3
# 1681                      322            1     18                  3
#
#       Trust Level_n  Safety Level_n Cluster       pol
# 0                 2               0       3  negative
# 1                 2               3       3  negative
# 2                 2               3       2  negative
# 3                 2               3       2  negative
# 4                 2               3       2  negative
# ...             ...             ...     ...       ...
# 1676              2               0       4  negative
# 1677              4               1       4  negative
# 1679              2               0       0  negative
# 1680              2               0       0  negative
# 1681              2               0       0  negative
#
# [878 rows x 31 columns]

# %%
#converting to numbers
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()

df["pol"] = lb.fit_transform(df["pol"])
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_19068\1018132002.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df
# Out:
#      Respondent Age  Gender  COVID-19 Jab?   Race  Any reason for Hesitation  \
# 0         Staff  19       2              1  White                        1.0
# 1       Student  20       2              0  White                        2.0
# 2       Student  19       1              0  White                        2.0
# 3       Student  44       1              0  White                        2.0
# 4         Staff  30       1              1  White                        2.0
# ...         ...  ..     ...            ...    ...                        ...
# 1676    Student  20       1              0  White                        2.0
# 1677    Student  18       1              0  White                        3.0
# 1679    Student  18       1              0  White                        1.0
# 1680    Student  20       1              0  White                        1.0
# 1681    Student  28       1              1  White                        1.0
#
#                                 Reasons for Hesitation  Hesistation Status  \
# 0                     Different things health long run                 NaN
# 1                     Different things health long run                 3.0
# 2                     Different things health long run                 3.0
# 3                     Different things health long run                 3.0
# 4                     Different things health long run                 0.0
# ...                                                ...                 ...
# 1676                allergies afraid allergic reaction                 3.0
# 1677                allergies afraid allergic reaction                 3.0
# 1679  relative newness vaccine given slight hesitation                 3.0
# 1680  relative newness vaccine given slight hesitation                 3.0
# 1681  relative newness vaccine given slight hesitation                 0.0
#
#          Trust Level     Safety Level  ... Accessibility_n Obstacles_n  \
# 0       Mostly trust      Mostly safe  ...             201         417
# 1       Mostly trust        Very safe  ...             201         425
# 2       Mostly trust        Very safe  ...             335         211
# 3       Mostly trust        Very safe  ...             335         211
# 4       Mostly trust        Very safe  ...             335         211
# ...              ...              ...  ...             ...         ...
# 1676    Mostly trust      Mostly safe  ...             251          34
# 1677  Somewhat trust  Not safe at all  ...             251          34
# 1679    Mostly trust      Mostly safe  ...             200         652
# 1680    Mostly trust      Mostly safe  ...             200         652
# 1681    Mostly trust      Mostly safe  ...             200         652
#
#      Reasons for Hesitation_n Respondent_n Race_n Confidence Level_n  \
# 0                          39            0     18                  3
# 1                          39            1     18                  4
# 2                          39            1     18                  4
# 3                          39            1     18                  4
# 4                          39            0     18                  4
# ...                       ...          ...    ...                ...
# 1676                      180            1     18                  3
# 1677                      180            1     18                  2
# 1679                      322            1     18                  3
# 1680                      322            1     18                  3
# 1681                      322            1     18                  3
#
#       Trust Level_n  Safety Level_n Cluster pol
# 0                 2               0       3   0
# 1                 2               3       3   0
# 2                 2               3       2   0
# 3                 2               3       2   0
# 4                 2               3       2   0
# ...             ...             ...     ...  ..
# 1676              2               0       4   0
# 1677              4               1       4   0
# 1679              2               0       0   0
# 1680              2               0       0   0
# 1681              2               0       0   0
#
# [878 rows x 31 columns]

# %%
X = tf.fit_transform(df['Reasons for Hesitation']).toarray()
y = df['pol']

# %%
# splitting the data into training and testing sets

from sklearn.model_selection import train_test_split

x_train2, x_test2, y_train2, y_test2 = train_test_split(X, y, test_size = 0.25, random_state = 40)

# print(x_train.shape)
# print(y_train.shape)
# print(x_test.shape)
# print(y_test.shape)


from sklearn.svm import SVC

model = SVC()
model.fit(x_train2, y_train2)

y_pred = model.predict(x_test2)

print("Testing Accuracy :", model.score(x_test2, y_test2))
# Out:
# Testing Accuracy : 0.9954545454545455

# %%
from sklearn import metrics

# %%
cf = metrics.confusion_matrix(y_test2, y_pred)

# %%
print(cf)
# Out:
# [[134   0]
#  [  1  85]]

# %%
sns.heatmap(cf)
# Out:
# <AxesSubplot:>

# %%
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = cf, display_labels = [False, True])

# %%
cm_display.plot()
plt.show()

# %%
F1_score = metrics.f1_score(y_test2, y_pred)

# %%
F1_score
# Out:
# 0.9941520467836257

# %%
clas_rep = metrics.classification_report(y_test2, y_pred)

# %%
print(clas_rep)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       134
#            1       1.00      0.99      0.99        86
#
#     accuracy                           1.00       220
#    macro avg       1.00      0.99      1.00       220
# weighted avg       1.00      1.00      1.00       220

# %% [markdown]
# # Prediciton

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,Dense, Dropout, SpatialDropout1D
from tensorflow.keras.layers import Embedding

# %%
sentiment_label = df["Reasons for Hesitation"].factorize()

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
covid = dataset['Reasons for Hesitation'].values
tokenizer = Tokenizer(num_words=5000)
encoded_docs = tokenizer.texts_to_sequences(covid)
padded_sequence = pad_sequences(encoded_docs, maxlen=5000)

# %%
text = input("Enter the text you want to predict")

# %%
def predict_sentiment(text):
    tw = tokenizer.texts_to_sequences([text])
    tw = pad_sequences(tw,maxlen=661)
    prediction = tr.predict(tw)
    #prediction = int(tr.predict(tw).round().item())
    if prediction == 0:
        return 'Negative. Not like to take the vaccine'
    else:
        return 'Positive. Likey to take the vaccine'
    #print("Predicted label: ", sentiment_label[1][prediction])

# %%
print(f"The result of your prediction is:" {predict_sentiment(text)})
